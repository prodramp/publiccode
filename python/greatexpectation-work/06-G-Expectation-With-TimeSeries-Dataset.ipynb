# %%
import pandas as pd
import great_expectations as ge

# %%
source_url = "https://raw.githubusercontent.com/prodramp/publiccode/master/datasets/supermarket_sales.csv"

# %% [markdown]
# ## Let Great Expectations to read the Data itself first¶

# %%
df = ge.read_csv(source_url)

# %%
df.sample(10)
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 110  479-26-8945      B   Mandalay        Member  Female
# 278  537-72-0426      C  Naypyitaw        Member    Male
# 212  142-63-6033      B   Mandalay        Normal    Male
# 442  138-17-5109      A     Yangon        Member  Female
# 84   360-39-5055      C  Naypyitaw        Member    Male
# 833  528-14-9470      A     Yangon        Member    Male
# 496  556-97-7101      C  Naypyitaw        Normal  Female
# 758  250-17-5703      A     Yangon        Member    Male
# 947  676-10-2200      B   Mandalay        Member    Male
# 742  373-14-0504      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%     Total  \
# 110       Sports and travel       16.49         2   1.6490   34.6290
# 278     Fashion accessories       70.99        10  35.4950  745.3950
# 212      Home and lifestyle       92.36         5  23.0900  484.8900
# ...

# %%
df.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count             1.000000e+03   1000.000000  1000.00000
# mean              4.761905e+00     15.379369     6.97270
# std               6.131498e-14     11.708825     1.71858
# min               4.761905e+00      0.508500     4.00000
# ...

# %%
df.expect_column_values_to_be_dateutil_parseable('Date')
# Out:
# {
#   "result": {
#     "element_count": 1000,
#     "missing_count": 0,
#     "missing_percent": 0.0,
#     "unexpected_count": 0,
#     "unexpected_percent": 0.0,
#     "unexpected_percent_total": 0.0,
#     "unexpected_percent_nonmissing": 0.0,
#     "partial_unexpected_list": []
#   },
#   "exception_info": {
#     "raised_exception": false,
#     "exception_traceback": null,
#     "exception_message": null
#   },
#   "meta": {},
#   "success": true
# }

# %%
df.expect_column_values_to_match_strftime_format(column="Date", strftime_format="%m/%d/%Y")
# Out:
# {
#   "result": {
#     "element_count": 1000,
#     "missing_count": 0,
#     "missing_percent": 0.0,
#     "unexpected_count": 0,
#     "unexpected_percent": 0.0,
#     "unexpected_percent_total": 0.0,
#     "unexpected_percent_nonmissing": 0.0,
#     "partial_unexpected_list": []
#   },
#   "exception_info": {
#     "raised_exception": false,
#     "exception_traceback": null,
#     "exception_message": null
#   },
#   "meta": {},
#   "success": true
# }

# %%
df.expect_column_values_to_match_strftime_format(column="Date", strftime_format="%Y-%m-%d %H:%M:%S")
# Out:
# {
#   "result": {
#     "element_count": 1000,
#     "missing_count": 0,
#     "missing_percent": 0.0,
#     "unexpected_count": 1000,
#     "unexpected_percent": 100.0,
#     "unexpected_percent_total": 100.0,
#     "unexpected_percent_nonmissing": 100.0,
#     "partial_unexpected_list": [
#       "1/5/2019",
#       "3/8/2019",
#       "3/3/2019",
#       "1/27/2019",
#       "2/8/2019",
#       "3/25/2019",
#       "2/25/2019",
#       "2/24/2019",
#       "1/10/2019",
#       "2/20/2019",
#       "2/6/2019",
#       "3/9/2019",
#       "2/12/2019",
#       "2/7/2019",
#       "3/29/2019",
#       "1/15/2019",
#       "3/11/2019",
#       "1/1/2019",
#       "1/21/2019",
#       "3/11/2019"
#     ]
#   },
#   "exception_info": {
#     "raised_exception": false,
#     "exception_traceback": null,
#     "exception_message": null
#   },
#   "meta": {},
#   "success": false
# }

# %%
df['DateTime'] = pd.to_datetime(df['Date'])

# %%
df.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count             1.000000e+03   1000.000000  1000.00000
# mean              4.761905e+00     15.379369     6.97270
# std               6.131498e-14     11.708825     1.71858
# min               4.761905e+00      0.508500     4.00000
# ...

# %%
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
df.expect_column_values_to_be_dateutil_parseable('DateTime')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/j9/zkczhkln1w95vm9cj3p_qzhr0000gp/T/ipykernel_66616/516696419.py in <module>
# ----> 1 df.expect_column_values_to_be_dateutil_parseable('DateTime')
#
# ~/anaconda3/envs/python38/lib/python3.8/site-packages/great_expectations/data_asset/util.py in f(*args, **kwargs)
#      74         @wraps(self.mthd, assigned=("__name__", "__module__"))
#      75         def f(*args, **kwargs):
# ---> 76             return self.mthd(obj, *args, **kwargs)
#      77
#      78         f.__doc__ = doc
#
# ~/anaconda3/envs/python38/lib/python3.8/site-packages/great_expectations/data_asset/data_asset.py in wrapper(self, *args, **kwargs)
#     285
#     286                         else:
# --> 287                             raise err
#     288
#     289                 else:
#
# ...

# %%
df.expect_column_values_to_match_strftime_format(column="DateTime", strftime_format="%Y-%m-%d %H:%M:%S")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/envs/python38/lib/python3.8/site-packages/great_expectations/dataset/pandas_dataset.py in is_parseable_by_format(val)
#    1473             try:
# -> 1474                 datetime.strptime(val, strftime_format)
#    1475                 return True
#
# TypeError: strptime() argument 1 must be str, not Timestamp
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# /var/folders/j9/zkczhkln1w95vm9cj3p_qzhr0000gp/T/ipykernel_66616/1531764559.py in <module>
# ----> 1 df.expect_column_values_to_match_strftime_format(column="DateTime", strftime_format="%Y-%m-%d %H:%M:%S")
#
# ~/anaconda3/envs/python38/lib/python3.8/site-packages/great_expectations/data_asset/util.py in f(*args, **kwargs)
# ...

# %% [markdown]
# # Why use apply() and tranform() on DataFrame?
#
# - Both apply() and transform() are used to manipulate an entire DataFrame or any specific column in given DataFrame.
#
#
# # 3 main differences
#
#
# - transform() can take a function, a string function, a list of functions, and a dict. However, apply() is only allowed a function.
# -  transform() cannot produce aggregated results
# - apply() works with multiple Series at a time. But, transform() is only allowed to work with a single Series at a time.

# %% [markdown]
# ## Source Notebook:
# - https://github.com/BindiChen/machine-learning/blob/master/data-analysis/014-pandas-apply-vs-transform/pandas-apply-vs-transform.ipynb
#
# Note: I am using most of the content here from the above source notebook. Please do review the above as needed.

# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame({'A': [1,2,3], 'B': [10,20,30] })

# %%
df
# Out:
#    A   B
# 0  1  10
# 1  2  20
# 2  3  30

# %%
def plus_10(x):
    return x+10

# %%
df.apply(plus_10)
# Out:
#     A   B
# 0  11  20
# 1  12  30
# 2  13  40

# %%
df['B'].apply(plus_10)
# Out:
# 0    20
# 1    30
# 2    40
# Name: B, dtype: int64

# %%
df
# Out:
#    A   B
# 0  1  10
# 1  2  20
# 2  3  30

# %%
df.transform(plus_10)
# Out:
#     A   B
# 0  11  20
# 1  12  30
# 2  13  40

# %%
df['B'].transform(plus_10)
# Out:
# 0    20
# 1    30
# 2    40
# Name: B, dtype: int64

# %%
df.apply(lambda x: x+10)
# Out:
#     A   B
# 0  11  20
# 1  12  30
# 2  13  40

# %%
df
# Out:
#    A   B
# 0  1  10
# 1  2  20
# 2  3  30

# %%
df.transform(lambda x: x+10)
# Out:
#     A   B
# 0  11  20
# 1  12  30
# 2  13  40

# %%
df['B'].transform(lambda x: x+10)
# Out:
# 0    20
# 1    30
# 2    40
# Name: B, dtype: int64

# %%
df['B_apply'] = df['B'].apply(plus_10)

# %%
df
# Out:
#    A   B  B_apply
# 0  1  10       20
# 1  2  20       30
# 2  3  30       40

# %%
# The lambda equivalent
df['B_apply_lambda'] = df['B'].apply(lambda x: x+10)

# %%
df
# Out:
#    A   B  B_apply  B_apply_lambda
# 0  1  10       20              20
# 1  2  20       30              30
# 2  3  30       40              40

# %%
df['B_transform'] = df['B'].transform(plus_10)

# %%
df
# Out:
#    A   B  B_apply  B_apply_lambda  B_transform
# 0  1  10       20              20           20
# 1  2  20       30              30           30
# 2  3  30       40              40           40

# %%
# The lambda equivalent
df['B_transform_lambda'] = df['B'].transform(lambda x: x+10)

# %%
df
# Out:
#    A   B  B_apply  B_apply_lambda  B_transform  B_transform_lambda
# 0  1  10       20              20           20                  20
# 1  2  20       30              30           30                  30
# 2  3  30       40              40           40                  40

# %% [markdown]
# # 3 main differences
# - transform() works with function, a string function, a list of functions, and a dict. However, apply() is only allowed with function.
# - transform() cannot produce aggregated results.
# - apply() works with multiple Series at a time. But, transform() is only allowed to work with a single Series at a time.

# %%
df
# Out:
#    A   B  B_apply  B_apply_lambda  B_transform  B_transform_lambda
# 0  1  10       20              20           20                  20
# 1  2  20       30              30           30                  30
# 2  3  30       40              40           40                  40

# %%
df.transform('sqrt')
# Out:
#           A         B   B_apply  B_apply_lambda  B_transform  \
# 0  1.000000  3.162278  4.472136        4.472136     4.472136
# 1  1.414214  4.472136  5.477226        5.477226     5.477226
# 2  1.732051  5.477226  6.324555        6.324555     6.324555
#
#    B_transform_lambda
# 0            4.472136
# 1            5.477226
# 2            6.324555

# %%
df
# Out:
#    A   B  B_apply  B_apply_lambda  B_transform  B_transform_lambda
# 0  1  10       20              20           20                  20
# 1  2  20       30              30           30                  30
# 2  3  30       40              40           40                  40

# %%
df.transform([np.sqrt, np.exp])
# Out:
#           A                    B                 B_apply                \
#        sqrt        exp      sqrt           exp      sqrt           exp
# 0  1.000000   2.718282  3.162278  2.202647e+04  4.472136  4.851652e+08
# 1  1.414214   7.389056  4.472136  4.851652e+08  5.477226  1.068647e+13
# 2  1.732051  20.085537  5.477226  1.068647e+13  6.324555  2.353853e+17
#
#   B_apply_lambda               B_transform               B_transform_lambda  \
#             sqrt           exp        sqrt           exp               sqrt
# 0       4.472136  4.851652e+08    4.472136  4.851652e+08           4.472136
# 1       5.477226  1.068647e+13    5.477226  1.068647e+13           5.477226
# 2       6.324555  2.353853e+17    6.324555  2.353853e+17           6.324555
#
#
#             exp
# 0  4.851652e+08
# 1  1.068647e+13
# 2  2.353853e+17

# %%
df.transform({
    'A': np.sqrt,
    'B': np.exp,
})
# Out:
#           A             B
# 0  1.000000  2.202647e+04
# 1  1.414214  4.851652e+08
# 2  1.732051  1.068647e+13

# %%
df.apply({
    'A': np.sqrt,
    'B': np.exp,
})
# Out:
#           A             B
# 0  1.000000  2.202647e+04
# 1  1.414214  4.851652e+08
# 2  1.732051  1.068647e+13

# %%
df
# Out:
#    A   B  B_apply  B_apply_lambda  B_transform  B_transform_lambda
# 0  1  10       20              20           20                  20
# 1  2  20       30              30           30                  30
# 2  3  30       40              40           40                  40

# %%
df.apply(lambda x:x.sum())
# Out:
# A                      6
# B                     60
# B_apply               90
# B_apply_lambda        90
# B_transform           90
# B_transform_lambda    90
# dtype: int64

# %%
# You will get an Error
#df.transform(lambda x:x.sum())

#Error Message>>> ValueError: transforms cannot produce aggregated results

# %%
def subtract_two(x):
    return x['B'] - x['A']

# %%
df.apply(subtract_two, axis=1)
# Out:
# 0     9
# 1    18
# 2    27
# dtype: int64

# %%
# You will get an Error
#df.transform(subtract_two, axis=1)

# ValueError: transforms cannot produce aggregated results

# %%
# It is working
df.apply(lambda x: x['B'] - x['A'], axis=1)
# Out:
# 0     9
# 1    18
# 2    27
# dtype: int64

# %%
# Getting same error
#df.transform(lambda x: x['B'] - x['A'], axis=1)

# ValueError: transforms cannot produce aggregated results

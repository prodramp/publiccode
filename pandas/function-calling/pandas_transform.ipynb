# %%
import pandas as pd
import numpy as np

# %%
remote_url = "https://raw.githubusercontent.com/prodramp/publiccode/master/datasets/titanic.csv"

# %%
df = pd.read_csv(remote_url)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
def change_age_times_5(x):
    return x*5

# %%
df['Age'].transform(change_age_times_5)
# Out:
# 0      110.0
# 1      190.0
# 2      130.0
# 3      175.0
# 4      175.0
#        ...
# 886    135.0
# 887     95.0
# 888      NaN
# 889    130.0
# 890    160.0
# Name: Age, Length: 891, dtype: float64

# %%
df.transform(change_age_times_5)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              5         0      15
# 1             10         5       5
# 2             15         5      15
# 3             20         5       5
# 4             25         0      15
# ..           ...       ...     ...
# 886         4435         0      10
# 887         4440         5       5
# 888         4445         0      15
# 889         4450         5       5
# 890         4455         0      15
#
#                                                   Name  \
# 0    Braund, Mr. Owen HarrisBraund, Mr. Owen Harris...
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2    Heikkinen, Miss. LainaHeikkinen, Miss. LainaHe...
# 3    Futrelle, Mrs. Jacques Heath (Lily May Peel)Fu...
# 4    Allen, Mr. William HenryAllen, Mr. William Hen...
# ..                                                 ...
# 886  Montvila, Rev. JuozasMontvila, Rev. JuozasMont...
# 887  Graham, Miss. Margaret EdithGraham, Miss. Marg...
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# You will get error
#df.transform('sqrt')

# %%
df['Pclass'].transform('s')
# Out:
# 0      1.732051
# 1      1.000000
# 2      1.732051
# 3      1.000000
# 4      1.732051
#          ...
# 886    1.414214
# 887    1.000000
# 888    1.732051
# 889    1.000000
# 890    1.732051
# Name: Pclass, Length: 891, dtype: float64

# %%
transform('')

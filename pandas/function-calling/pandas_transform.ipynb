# %%
import pandas as pd
import numpy as np

# %%
# Only added to display images for explaining the concept
from IPython.display import Image, display
display(Image(url='https://github.com/prodramp/publiccode/blob/master/images/transform-example.png?raw=true', width=800, unconfined=True))
print("Image source: https://pbpython.com/pandas_transform.html")
# Out:
# <img src="https://github.com/prodramp/publiccode/blob/master/images/transform-example.png?raw=true" width="800" class="unconfined"/>
# Image source: https://pbpython.com/pandas_transform.html

# %% [markdown]
# ### Source Dataset:
# - https://www.kaggle.com/aungpyaeap/supermarket-sales

# %%
remote_url = "https://raw.githubusercontent.com/prodramp/publiccode/master/datasets/supermarket_sales.csv"

# %%
df = pd.read_csv(remote_url)

# %%
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
def change_income_times_5(x):
    return x*5

# %%
df['gross income'].transform(change_income_times_5)
# Out:
# 0      130.7075
# 1       19.1000
# 2       81.0775
# 3      116.4400
# 4      151.0425
#          ...
# 995     10.0875
# 996    243.4500
# 997      7.9600
# 998     16.4550
# 999    154.5950
# Name: gross income, Length: 1000, dtype: float64

# %%
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
df.transform(change_income_times_5)
# Out:
#                                             Invoice ID Branch  \
# 0    750-67-8428750-67-8428750-67-8428750-67-842875...  AAAAA
# 1    226-31-3081226-31-3081226-31-3081226-31-308122...  CCCCC
# 2    631-41-3108631-41-3108631-41-3108631-41-310863...  AAAAA
# 3    123-19-1176123-19-1176123-19-1176123-19-117612...  AAAAA
# 4    373-73-7910373-73-7910373-73-7910373-73-791037...  AAAAA
# ..                                                 ...    ...
# 995  233-67-5758233-67-5758233-67-5758233-67-575823...  CCCCC
# 996  303-96-2227303-96-2227303-96-2227303-96-222730...  BBBBB
# 997  727-02-1313727-02-1313727-02-1313727-02-131372...  AAAAA
# 998  347-56-2442347-56-2442347-56-2442347-56-244234...  AAAAA
# 999  849-09-3807849-09-3807849-09-3807849-09-380784...  AAAAA
#
#                                               City  \
# 0                   YangonYangonYangonYangonYangon
# 1    NaypyitawNaypyitawNaypyitawNaypyitawNaypyitaw
# 2                   YangonYangonYangonYangonYangon
# ...

# %%
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
# You will get error
#df.transform('sqrt')

# %%
df['Total'].transform('sqrt')
# Out:
# 0      23.430141
# 1       8.956562
# 2      18.453333
# 3      22.114430
# 4      25.186872
#          ...
# 995     6.509032
# 996    31.976398
# 997     5.782041
# 998     8.313303
# 999    25.481346
# Name: Total, Length: 1000, dtype: float64

# %%
# Will generate the error also with - sum,min,max,mean,median
# df['Total'].transform('max')

# %%
df['Total'].transform('square')
# Out:
# 0      3.013697e+05
# 1      6.435248e+03
# 2      1.159576e+05
# 3      2.391679e+05
# 4      4.024361e+05
#            ...
# 995    1.795005e+03
# 996    1.045486e+06
# 997    1.117699e+03
# 998    4.776330e+03
# 999    4.215892e+05
# Name: Total, Length: 1000, dtype: float64

# %%
df.apply('sum')
# Out:
# Invoice ID                   750-67-8428226-31-3081631-41-3108123-19-117637...
# Branch                       ACAAACACABBBAAABAAABCBBAAABABABBBACCAACBBCBCCB...
# City                         YangonNaypyitawYangonYangonYangonNaypyitawYang...
# Customer type                MemberNormalNormalMemberNormalNormalMemberNorm...
# Gender                       FemaleFemaleMaleMaleMaleMaleFemaleFemaleFemale...
# Product line                 Health and beautyElectronic accessoriesHome an...
# Unit price                                                             55672.1
# Quantity                                                                  5510
# Tax 5%                                                                 15379.4
# Total                                                                   322967
# Date                         1/5/20193/8/20193/3/20191/27/20192/8/20193/25/...
# Time                         13:0810:2913:2320:3310:3718:3014:3611:3817:151...
# ...

# %%
df['Total'].apply('sum')
# Out:
# 322966.74899999995

# %%
df['Total'].apply('square')
# Out:
# 0      3.013697e+05
# 1      6.435248e+03
# 2      1.159576e+05
# 3      2.391679e+05
# 4      4.024361e+05
#            ...
# 995    1.795005e+03
# 996    1.045486e+06
# 997    1.117699e+03
# 998    4.776330e+03
# 999    4.215892e+05
# Name: Total, Length: 1000, dtype: float64

# %%
#function - square,sqrt - per row
#agg> sum,min,max,mean,median,

# %%
df['Total'].transform('square')

# %%
df['Total'].transform([np.sqrt, np.exp])
# Out:
#           sqrt            exp
# 0    23.430141  2.601915e+238
# 1     8.956562   6.904041e+34
# 2    18.453333  7.732957e+147
# 3    22.114430  2.459505e+212
# 4    25.186872  3.214267e+275
# ..         ...            ...
# 995   6.509032   2.511721e+18
# 996  31.976398            inf
# 997   5.782041   3.306230e+14
# 998   8.313303   1.034013e+30
# 999  25.481346  9.704492e+281
#
# [1000 rows x 2 columns]

# %%
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
df.groupby('Payment')['Total'].apply(sum)
# Out:
# Payment
# Cash           112206.570
# Credit card    100767.072
# Ewallet        109993.107
# Name: Total, dtype: float64

# %%
df.groupby('Payment')['Total'].transform(sum)
# Out:
# 0      109993.107
# 1      112206.570
# 2      100767.072
# 3      109993.107
# 4      109993.107
#           ...
# 995    109993.107
# 996    109993.107
# 997    112206.570
# 998    112206.570
# 999    112206.570
# Name: Total, Length: 1000, dtype: float64

# %%
df.groupby('Payment')['Total'].apply(sum).rename('payment_total_result').reset_index()
# Out:
#        Payment  payment_total_result
# 0         Cash            112206.570
# 1  Credit card            100767.072
# 2      Ewallet            109993.107

# %%
df_payment_total_result = df.groupby('Payment')['Total'].apply(sum).rename('payment_total_result').reset_index()

# %%
type(df_payment_total_result)
# Out:
# pandas.core.frame.DataFrame

# %%
df.groupby('Payment')['Total'].sum().rename('payment_total_result').reset_index()
# Out:
#        Payment  payment_total_result
# 0         Cash            112206.570
# 1  Credit card            100767.072
# 2      Ewallet            109993.107

# %%
df.groupby('Payment')['Total'].median().rename('payment_total_result').reset_index()
# Out:
#        Payment  payment_total_result
# 0         Cash               262.962
# 1  Credit card               239.589
# 2      Ewallet               253.680

# %%
df.groupby('Payment')['Total'].min().rename('payment_total_result').reset_index()
# Out:
#        Payment  payment_total_result
# 0         Cash               10.6785
# 1  Credit card               12.6945
# 2      Ewallet               13.4190

# %%
df.groupby('Payment')['Total'].max().rename('payment_total_result').reset_index()
# Out:
#        Payment  payment_total_result
# 0         Cash               1003.59
# 1  Credit card               1042.65
# 2      Ewallet               1034.46

# %%
# Step 2: merge
df_total_result = df.groupby('Payment')['Total'].sum().rename('payment_total_result').reset_index()
df_total_result
# Out:
#        Payment  payment_total_result
# 0         Cash            112206.570
# 1  Credit card            100767.072
# 2      Ewallet            109993.107

# %%
df_updated = pd.merge(df, df_total_result, how='left')

# %%
df_updated
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
# Step 1
df['payment_total_result'] = df.groupby('Payment')['Total'].transform(sum)

# %%
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
df['Total_percentage'] = df['Total'] / df['payment_total_result']

# %%
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
df['Total_percentage'] = df['Total_percentage'].apply(lambda x: format(x, '.2%'))
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
## Filtering Data

# %%
df.groupby('Product line').size()
# Out:
# Product line
# Electronic accessories    170
# Fashion accessories       178
# Food and beverages        174
# Health and beauty         152
# Home and lifestyle        160
# Sports and travel         166
# dtype: int64

# %%
df.groupby('Product line')['Total'].transform('sum')
# Out:
# 0      49193.7390
# 1      54337.5315
# 2      53861.9130
# 3      49193.7390
# 4      55122.8265
#           ...
# 995    49193.7390
# 996    53861.9130
# 997    56144.8440
# 998    53861.9130
# 999    54305.8950
# Name: Total, Length: 1000, dtype: float64

# %%
df.groupby('Customer type')['Total'].transform('sum')
# Out:
# 0      164223.444
# 1      158743.305
# 2      158743.305
# 3      164223.444
# 4      158743.305
#           ...
# 995    158743.305
# 996    158743.305
# 997    164223.444
# 998    158743.305
# 999    164223.444
# Name: Total, Length: 1000, dtype: float64

# %%
df.groupby('Customer type')['Total'].sum()
# Out:
# Customer type
# Member    164223.444
# Normal    158743.305
# Name: Total, dtype: float64

# %%
df.groupby('Gender')['Total'].sum()
# Out:
# Gender
# Female    167882.925
# Male      155083.824
# Name: Total, dtype: float64

# %%
df.groupby('Gender')['Total'].transform('sum')
# Out:
# 0      167882.925
# 1      167882.925
# 2      155083.824
# 3      155083.824
# 4      155083.824
#           ...
# 995    155083.824
# 996    167882.925
# 997    155083.824
# 998    155083.824
# 999    167882.925
# Name: Total, Length: 1000, dtype: float64

# %%
df['product_line_total_result'] = df.groupby('Product line')['Total'].transform('sum')

# %%
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

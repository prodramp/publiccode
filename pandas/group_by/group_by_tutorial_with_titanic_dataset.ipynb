# %% [markdown]
# # In general group by process "split-apply-combine" for the given data frame
#
# - Splitting the data into groups
# - Applying a function to each group independently
# - Combining the results into a data structure
#
# Source: https://github.com/BindiChen/machine-learning/blob/master/data-analysis/032-pandas-groupby/pandas-groupby.ipynb
#
# ### Note:
# - This jupyter notebook is inspired from the above source
# - I have added various other details to this notebook which are not available in the above notebook

# %%
import pandas as pd
import numpy as np

# %%
remote_url = "https://raw.githubusercontent.com/prodramp/publiccode/master/datasets/titanic.csv"

# %%
df = pd.read_csv(remote_url)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
df['Sex'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
df['Pclass'].unique()
# Out:
# array([3, 1, 2])

# %%
df['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
df['Survived'].unique()
# Out:
# array([0, 1])

# %%
df['Cabin'].unique()
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
#        'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#        'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#        'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#        'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#        'T', 'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44',
#        'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14',
#        'B37', 'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38',
#        'B39', 'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68',
#        'B41', 'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48',
#        'E58', 'C126', 'B71', 'B51 B53 B55', 'D49', 'B5', 'B20', 'F G63',
#        'C62 C64', 'E24', 'C90', 'C45', 'E8', 'B101', 'D45', 'C46', 'D30',
#        'E121', 'D11', 'E77', 'F38', 'B3', 'D6', 'B82 B84', 'D17', 'A36',
#        'B102', 'B69', 'E49', 'C47', 'D28', 'E17', 'A24', 'C50', 'B42',
#        'C148'], dtype=object)

# %%
df_groupby_sex = df.groupby('Sex')

# %%
df_groupby_sex

# %%
type(df_groupby_sex)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
df_groupby_sex.ngroups
# Out:
# 2

# %%
df_groupby_sex.groups
# Out:
# {'female': Int64Index([  1,   2,   3,   8,   9,  10,  11,  14,  15,  18,
#              ...
#              866, 871, 874, 875, 879, 880, 882, 885, 887, 888],
#             dtype='int64', length=314),
#  'male': Int64Index([  0,   4,   5,   6,   7,  12,  13,  16,  17,  20,
#              ...
#              873, 876, 877, 878, 881, 883, 884, 886, 889, 890],
#             dtype='int64', length=577)}

# %%
df_groupby_sex.size()
# Out:
# Sex
# female    314
# male      577
# dtype: int64

# %%
df_groupby_sex.groups

# %%
df_groupby_sex.first()
# Out:
#         PassengerId  Survived  Pclass  \
# Sex
# female            2         1       1
# male              1         0       3
#
#                                                      Name   Age  SibSp  Parch  \
# Sex
# female  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# male                              Braund, Mr. Owen Harris  22.0      1      0
#
#            Ticket     Fare Cabin Embarked
# Sex
# female   PC 17599  71.2833   C85        C
# male    A/5 21171   7.2500   E46        S

# %%
df_groupby_sex.last()
# Out:
#         PassengerId  Survived  Pclass  \
# Sex
# female          889         0       3
# male            891         0       3
#
#                                             Name   Age  SibSp  Parch  \
# Sex
# female  Johnston, Miss. Catherine Helen "Carrie"  19.0      1      2
# male                         Dooley, Mr. Patrick  32.0      0      0
#
#             Ticket   Fare Cabin Embarked
# Sex
# female  W./C. 6607  23.45   B42        S
# male        370376   7.75  C148        Q

# %%
# To retrieve one of the created groups
df_sex_female = df_groupby_sex.get_group('female')

# %%
df_sex_female
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 880          881         1       2
# 882          883         0       3
# 885          886         0       3
# 887          888         1       1
# 888          889         0       3
#
#                                                   Name   Age  SibSp  Parch  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                               Heikkinen, Miss. Laina  26.0      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  27.0      0      2
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  14.0      1      0
# ..                                                 ...   ...    ...    ...
# 880       Shelley, Mrs. William (Imanita Parrish Hall)  25.0      0      1
# 882                       Dahlberg, Miss. Gerda Ulrika  22.0      0      0
# 885               Rice, Mrs. William (Margaret Norton)  39.0      0      5
# 887                       Graham, Miss. Margaret Edith  19.0      0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"   NaN      1      2
#
#                Ticket     Fare Cabin Embarked
# 1            PC 17599  71.2833   C85        C
# 2    STON/O2. 3101282   7.9250   NaN        S
# 3              113803  53.1000  C123        S
# 8              347742  11.1333   NaN        S
# 9              237736  30.0708   NaN        C
# ..                ...      ...   ...      ...
# 880            230433  26.0000   NaN        S
# 882              7552  10.5167   NaN        S
# 885            382652  29.1250   NaN        Q
# 887            112053  30.0000   B42        S
# 888        W./C. 6607  23.4500   NaN        S
#
# [314 rows x 11 columns]

# %%
df_sex_male = df_groupby_sex.get_group('male')

# %%
df_sex_male
# Out:
#      PassengerId  Survived  Pclass                            Name   Age  \
# 0              1         0       3         Braund, Mr. Owen Harris  22.0
# 4              5         0       3        Allen, Mr. William Henry  35.0
# 5              6         0       3                Moran, Mr. James   NaN
# 6              7         0       1         McCarthy, Mr. Timothy J  54.0
# 7              8         0       3  Palsson, Master. Gosta Leonard   2.0
# ..           ...       ...     ...                             ...   ...
# 883          884         0       2   Banfield, Mr. Frederick James  28.0
# 884          885         0       3          Sutehall, Mr. Henry Jr  25.0
# 886          887         0       2           Montvila, Rev. Juozas  27.0
# 889          890         1       1           Behr, Mr. Karl Howell  26.0
# 890          891         0       3             Dooley, Mr. Patrick  32.0
#
#      SibSp  Parch            Ticket     Fare Cabin Embarked
# 0        1      0         A/5 21171   7.2500   NaN        S
# 4        0      0            373450   8.0500   NaN        S
# 5        0      0            330877   8.4583   NaN        Q
# 6        0      0             17463  51.8625   E46        S
# 7        3      1            349909  21.0750   NaN        S
# ..     ...    ...               ...      ...   ...      ...
# 883      0      0  C.A./SOTON 34068  10.5000   NaN        S
# 884      0      0   SOTON/OQ 392076   7.0500   NaN        S
# 886      0      0            211536  13.0000   NaN        S
# 889      0      0            111369  30.0000  C148        C
# 890      0      0            370376   7.7500   NaN        Q
#
# [577 rows x 11 columns]

# %%
df_groupby_sex

# %% [markdown]
# ## Groups as keys

# %%
df_groupby_sex.groups.keys()
# Out:
# dict_keys(['female', 'male'])

# %%
group_by_keys = df_groupby_sex.groups.keys()

# %%
group_by_keys
# Out:
# dict_keys(['female', 'male'])

# %%
len(group_by_keys)
# Out:
# 2

# %%
type(group_by_keys)
# Out:
# dict_keys

# %%
for each_key in group_by_keys:
    print(each_key)
# Out:
# female
# male

# %%
keys = [key for key in group_by_keys]

# %%
keys
# Out:
# ['female', 'male']

# %%
keys[0]
# Out:
# 'female'

# %%
keys[1]
# Out:
# 'male'

# %%
dict(list(df_groupby_sex))[keys[0]]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 880          881         1       2
# 882          883         0       3
# 885          886         0       3
# 887          888         1       1
# 888          889         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# 880       Shelley, Mrs. William (Imanita Parrish Hall)  female  25.0      0
# 882                       Dahlberg, Miss. Gerda Ulrika  female  22.0      0
# 885               Rice, Mrs. William (Margaret Norton)  female  39.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
#
#      Parch            Ticket     Fare Cabin Embarked
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 8        2            347742  11.1333   NaN        S
# 9        0            237736  30.0708   NaN        C
# ..     ...               ...      ...   ...      ...
# 880      1            230433  26.0000   NaN        S
# 882      0              7552  10.5167   NaN        S
# 885      5            382652  29.1250   NaN        Q
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
#
# [314 rows x 12 columns]

# %%
dict(list(df_groupby_sex))[keys[1]]
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# ..           ...       ...     ...                             ...   ...
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 889          890         1       1           Behr, Mr. Karl Howell  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0    22.0      1      0         A/5 21171   7.2500   NaN        S
# 4    35.0      0      0            373450   8.0500   NaN        S
# 5     NaN      0      0            330877   8.4583   NaN        Q
# 6    54.0      0      0             17463  51.8625   E46        S
# 7     2.0      3      1            349909  21.0750   NaN        S
# ..    ...    ...    ...               ...      ...   ...      ...
# 883  28.0      0      0  C.A./SOTON 34068  10.5000   NaN        S
# 884  25.0      0      0   SOTON/OQ 392076   7.0500   NaN        S
# 886  27.0      0      0            211536  13.0000   NaN        S
# 889  26.0      0      0            111369  30.0000  C148        C
# 890  32.0      0      0            370376   7.7500   NaN        Q
#
# [577 rows x 12 columns]

# %%
for each_key in group_by_keys:
    x = df_groupby_sex.get_group(each_key)
    print(x)
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 880          881         1       2
# 882          883         0       3
# 885          886         0       3
# 887          888         1       1
# 888          889         0       3
#
#                                                   Name   Age  SibSp  Parch  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                               Heikkinen, Miss. Laina  26.0      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  27.0      0      2
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  14.0      1      0
# ..                                                 ...   ...    ...    ...
# 880       Shelley, Mrs. William (Imanita Parrish Hall)  25.0      0      1
# 882                       Dahlberg, Miss. Gerda Ulrika  22.0      0      0
# 885               Rice, Mrs. William (Margaret Norton)  39.0      0      5
# 887                       Graham, Miss. Margaret Edith  19.0      0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"   NaN      1      2
#
#                Ticket     Fare Cabin Embarked
# 1            PC 17599  71.2833   C85        C
# 2    STON/O2. 3101282   7.9250   NaN        S
# 3              113803  53.1000  C123        S
# 8              347742  11.1333   NaN        S
# 9              237736  30.0708   NaN        C
# ..                ...      ...   ...      ...
# 880            230433  26.0000   NaN        S
# 882              7552  10.5167   NaN        S
# 885            382652  29.1250   NaN        Q
# 887            112053  30.0000   B42        S
# 888        W./C. 6607  23.4500   NaN        S
#
# [314 rows x 11 columns]
#      PassengerId  Survived  Pclass                            Name   Age  \
# 0              1         0       3         Braund, Mr. Owen Harris  22.0
# 4              5         0       3        Allen, Mr. William Henry  35.0
# 5              6         0       3                Moran, Mr. James   NaN
# 6              7         0       1         McCarthy, Mr. Timothy J  54.0
# 7              8         0       3  Palsson, Master. Gosta Leonard   2.0
# ..           ...       ...     ...                             ...   ...
# 883          884         0       2   Banfield, Mr. Frederick James  28.0
# 884          885         0       3          Sutehall, Mr. Henry Jr  25.0
# 886          887         0       2           Montvila, Rev. Juozas  27.0
# 889          890         1       1           Behr, Mr. Karl Howell  26.0
# 890          891         0       3             Dooley, Mr. Patrick  32.0
#
#      SibSp  Parch            Ticket     Fare Cabin Embarked
# 0        1      0         A/5 21171   7.2500   NaN        S
# 4        0      0            373450   8.0500   NaN        S
# 5        0      0            330877   8.4583   NaN        Q
# 6        0      0             17463  51.8625   E46        S
# 7        3      1            349909  21.0750   NaN        S
# ..     ...    ...               ...      ...   ...      ...
# 883      0      0  C.A./SOTON 34068  10.5000   NaN        S
# 884      0      0   SOTON/OQ 392076   7.0500   NaN        S
# 886      0      0            211536  13.0000   NaN        S
# 889      0      0            111369  30.0000  C148        C
# 890      0      0            370376   7.7500   NaN        Q
#
# [577 rows x 11 columns]

# %%
for each_key in group_by_keys:
    print(dict(list(df_groupby_sex))[each_key])
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 880          881         1       2
# 882          883         0       3
# 885          886         0       3
# 887          888         1       1
# 888          889         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# 880       Shelley, Mrs. William (Imanita Parrish Hall)  female  25.0      0
# 882                       Dahlberg, Miss. Gerda Ulrika  female  22.0      0
# 885               Rice, Mrs. William (Margaret Norton)  female  39.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
#
#      Parch            Ticket     Fare Cabin Embarked
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 8        2            347742  11.1333   NaN        S
# 9        0            237736  30.0708   NaN        C
# ..     ...               ...      ...   ...      ...
# 880      1            230433  26.0000   NaN        S
# 882      0              7552  10.5167   NaN        S
# 885      5            382652  29.1250   NaN        Q
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
#
# [314 rows x 12 columns]
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# ..           ...       ...     ...                             ...   ...
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 889          890         1       1           Behr, Mr. Karl Howell  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0    22.0      1      0         A/5 21171   7.2500   NaN        S
# 4    35.0      0      0            373450   8.0500   NaN        S
# 5     NaN      0      0            330877   8.4583   NaN        Q
# 6    54.0      0      0             17463  51.8625   E46        S
# 7     2.0      3      1            349909  21.0750   NaN        S
# ..    ...    ...    ...               ...      ...   ...      ...
# 883  28.0      0      0  C.A./SOTON 34068  10.5000   NaN        S
# 884  25.0      0      0   SOTON/OQ 392076   7.0500   NaN        S
# 886  27.0      0      0            211536  13.0000   NaN        S
# 889  26.0      0      0            111369  30.0000  C148        C
# 890  32.0      0      0            370376   7.7500   NaN        Q
#
# [577 rows x 12 columns]

# %% [markdown]
# ## Raw data processing

# %%
list(df_groupby_sex)
# Out:
# [('female',
#        PassengerId  Survived  Pclass  \
#   1              2         1       1
#   2              3         1       3
#   3              4         1       1
#   8              9         1       3
#   9             10         1       2
#   ..           ...       ...     ...
#   880          881         1       2
#   882          883         0       3
#   885          886         0       3
#   887          888         1       1
#   888          889         0       3
#
#                                                     Name     Sex   Age  SibSp  \
#   1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#   2                               Heikkinen, Miss. Laina  female  26.0      0
#   3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
#   8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
#   9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#   ..                                                 ...     ...   ...    ...
#   880       Shelley, Mrs. William (Imanita Parrish Hall)  female  25.0      0
#   882                       Dahlberg, Miss. Gerda Ulrika  female  22.0      0
#   885               Rice, Mrs. William (Margaret Norton)  female  39.0      0
#   887                       Graham, Miss. Margaret Edith  female  19.0      0
#   888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
#
#        Parch            Ticket     Fare Cabin Embarked
#   1        0          PC 17599  71.2833   C85        C
#   2        0  STON/O2. 3101282   7.9250   NaN        S
#   3        0            113803  53.1000  C123        S
#   8        2            347742  11.1333   NaN        S
#   9        0            237736  30.0708   NaN        C
#   ..     ...               ...      ...   ...      ...
#   880      1            230433  26.0000   NaN        S
#   882      0              7552  10.5167   NaN        S
#   885      5            382652  29.1250   NaN        Q
#   887      0            112053  30.0000   B42        S
#   888      2        W./C. 6607  23.4500   NaN        S
#
#   [314 rows x 12 columns]),
#  ('male',
#        PassengerId  Survived  Pclass                            Name   Sex  \
#   0              1         0       3         Braund, Mr. Owen Harris  male
#   4              5         0       3        Allen, Mr. William Henry  male
#   5              6         0       3                Moran, Mr. James  male
#   6              7         0       1         McCarthy, Mr. Timothy J  male
#   7              8         0       3  Palsson, Master. Gosta Leonard  male
#   ..           ...       ...     ...                             ...   ...
#   883          884         0       2   Banfield, Mr. Frederick James  male
#   884          885         0       3          Sutehall, Mr. Henry Jr  male
#   886          887         0       2           Montvila, Rev. Juozas  male
#   889          890         1       1           Behr, Mr. Karl Howell  male
#   890          891         0       3             Dooley, Mr. Patrick  male
#
#         Age  SibSp  Parch            Ticket     Fare Cabin Embarked
#   0    22.0      1      0         A/5 21171   7.2500   NaN        S
#   4    35.0      0      0            373450   8.0500   NaN        S
#   5     NaN      0      0            330877   8.4583   NaN        Q
#   6    54.0      0      0             17463  51.8625   E46        S
#   7     2.0      3      1            349909  21.0750   NaN        S
#   ..    ...    ...    ...               ...      ...   ...      ...
#   883  28.0      0      0  C.A./SOTON 34068  10.5000   NaN        S
#   884  25.0      0      0   SOTON/OQ 392076   7.0500   NaN        S
#   886  27.0      0      0            211536  13.0000   NaN        S
#   889  26.0      0      0            111369  30.0000  C148        C
#   890  32.0      0      0            370376   7.7500   NaN        Q
#
#   [577 rows x 12 columns])]

# %%
dict(list(df_groupby_sex))
# Out:
# {'female':      PassengerId  Survived  Pclass  \
#  1              2         1       1
#  2              3         1       3
#  3              4         1       1
#  8              9         1       3
#  9             10         1       2
#  ..           ...       ...     ...
#  880          881         1       2
#  882          883         0       3
#  885          886         0       3
#  887          888         1       1
#  888          889         0       3
#
#                                                    Name     Sex   Age  SibSp  \
#  1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#  2                               Heikkinen, Miss. Laina  female  26.0      0
#  3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
#  8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
#  9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#  ..                                                 ...     ...   ...    ...
#  880       Shelley, Mrs. William (Imanita Parrish Hall)  female  25.0      0
#  882                       Dahlberg, Miss. Gerda Ulrika  female  22.0      0
#  885               Rice, Mrs. William (Margaret Norton)  female  39.0      0
#  887                       Graham, Miss. Margaret Edith  female  19.0      0
#  888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
#
#       Parch            Ticket     Fare Cabin Embarked
#  1        0          PC 17599  71.2833   C85        C
#  2        0  STON/O2. 3101282   7.9250   NaN        S
#  3        0            113803  53.1000  C123        S
#  8        2            347742  11.1333   NaN        S
#  9        0            237736  30.0708   NaN        C
#  ..     ...               ...      ...   ...      ...
#  880      1            230433  26.0000   NaN        S
#  882      0              7552  10.5167   NaN        S
#  885      5            382652  29.1250   NaN        Q
#  887      0            112053  30.0000   B42        S
#  888      2        W./C. 6607  23.4500   NaN        S
#
#  [314 rows x 12 columns],
#  'male':      PassengerId  Survived  Pclass                            Name   Sex  \
#  0              1         0       3         Braund, Mr. Owen Harris  male
#  4              5         0       3        Allen, Mr. William Henry  male
#  5              6         0       3                Moran, Mr. James  male
#  6              7         0       1         McCarthy, Mr. Timothy J  male
#  7              8         0       3  Palsson, Master. Gosta Leonard  male
#  ..           ...       ...     ...                             ...   ...
#  883          884         0       2   Banfield, Mr. Frederick James  male
#  884          885         0       3          Sutehall, Mr. Henry Jr  male
#  886          887         0       2           Montvila, Rev. Juozas  male
#  889          890         1       1           Behr, Mr. Karl Howell  male
#  890          891         0       3             Dooley, Mr. Patrick  male
#
#        Age  SibSp  Parch            Ticket     Fare Cabin Embarked
#  0    22.0      1      0         A/5 21171   7.2500   NaN        S
#  4    35.0      0      0            373450   8.0500   NaN        S
#  5     NaN      0      0            330877   8.4583   NaN        Q
#  6    54.0      0      0             17463  51.8625   E46        S
#  7     2.0      3      1            349909  21.0750   NaN        S
#  ..    ...    ...    ...               ...      ...   ...      ...
#  883  28.0      0      0  C.A./SOTON 34068  10.5000   NaN        S
#  884  25.0      0      0   SOTON/OQ 392076   7.0500   NaN        S
#  886  27.0      0      0            211536  13.0000   NaN        S
#  889  26.0      0      0            111369  30.0000  C148        C
#  890  32.0      0      0            370376   7.7500   NaN        Q
#
#  [577 rows x 12 columns]}

# %%
dict(list(df_groupby_sex))['male']
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# ..           ...       ...     ...                             ...   ...
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 889          890         1       1           Behr, Mr. Karl Howell  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0    22.0      1      0         A/5 21171   7.2500   NaN        S
# 4    35.0      0      0            373450   8.0500   NaN        S
# 5     NaN      0      0            330877   8.4583   NaN        Q
# 6    54.0      0      0             17463  51.8625   E46        S
# 7     2.0      3      1            349909  21.0750   NaN        S
# ..    ...    ...    ...               ...      ...   ...      ...
# 883  28.0      0      0  C.A./SOTON 34068  10.5000   NaN        S
# 884  25.0      0      0   SOTON/OQ 392076   7.0500   NaN        S
# 886  27.0      0      0            211536  13.0000   NaN        S
# 889  26.0      0      0            111369  30.0000  C148        C
# 890  32.0      0      0            370376   7.7500   NaN        Q
#
# [577 rows x 12 columns]

# %%
dict(list(df_groupby_sex))['female']
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 880          881         1       2
# 882          883         0       3
# 885          886         0       3
# 887          888         1       1
# 888          889         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# 880       Shelley, Mrs. William (Imanita Parrish Hall)  female  25.0      0
# 882                       Dahlberg, Miss. Gerda Ulrika  female  22.0      0
# 885               Rice, Mrs. William (Margaret Norton)  female  39.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
#
#      Parch            Ticket     Fare Cabin Embarked
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 8        2            347742  11.1333   NaN        S
# 9        0            237736  30.0708   NaN        C
# ..     ...               ...      ...   ...      ...
# 880      1            230433  26.0000   NaN        S
# 882      0              7552  10.5167   NaN        S
# 885      5            382652  29.1250   NaN        Q
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
#
# [314 rows x 12 columns]

# %% [markdown]
# ## Processing Another Group

# %%
df_group_pclass = df.groupby('Pclass')

# %%
df_group_pclass

# %%
df_group_pclass.ngroups
# Out:
# 3

# %%
df_group_pclass.ngroup
# Out:
# <bound method GroupBy.ngroup of <pandas.core.groupby.generic.DataFrameGroupBy object at 0x7fdcb87e39d0>>

# %%
df_group_pclass.size()
# Out:
# Pclass
# 1    216
# 2    184
# 3    491
# dtype: int64

# %%
df_group_pclass.groups
# Out:
# {1: Int64Index([  1,   3,   6,  11,  23,  27,  30,  31,  34,  35,
#              ...
#              853, 856, 857, 862, 867, 871, 872, 879, 887, 889],
#             dtype='int64', length=216),
#  2: Int64Index([  9,  15,  17,  20,  21,  33,  41,  43,  53,  56,
#              ...
#              848, 854, 861, 864, 865, 866, 874, 880, 883, 886],
#             dtype='int64', length=184),
#  3: Int64Index([  0,   2,   4,   5,   7,   8,  10,  12,  13,  14,
#              ...
#              875, 876, 877, 878, 881, 882, 884, 885, 888, 890],
#             dtype='int64', length=491)}

# %%
df_group_pclass.first()
# Out:
#         PassengerId  Survived  \
# Pclass
# 1                 2         1
# 2                10         1
# 3                 1         0
#
#                                                      Name     Sex   Age  \
# Pclass
# 1       Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                     Nasser, Mrs. Nicholas (Adele Achem)  female  14.0
# 3                                 Braund, Mr. Owen Harris    male  22.0
#
#         SibSp  Parch     Ticket     Fare Cabin Embarked
# Pclass
# 1           1      0   PC 17599  71.2833   C85        C
# 2           1      0     237736  30.0708   D56        C
# 3           1      0  A/5 21171   7.2500    G6        S

# %%
df_group_pclass.last()
# Out:
#         PassengerId  Survived                   Name   Sex   Age  SibSp  \
# Pclass
# 1               890         1  Behr, Mr. Karl Howell  male  26.0      0
# 2               887         0  Montvila, Rev. Juozas  male  27.0      0
# 3               891         0    Dooley, Mr. Patrick  male  32.0      0
#
#         Parch  Ticket   Fare Cabin Embarked
# Pclass
# 1           0  111369  30.00  C148        C
# 2           0  211536  13.00   E77        S
# 3           0  370376   7.75  E121        Q

# %% [markdown]
# # Listing all the methods available on groupby object

# %%
import IPython

methods = [method_name for method_name in dir(df_groupby_sex) 
           if callable(getattr(df_groupby_sex, method_name)) & ~method_name.startswith('_')]

print(IPython.utils.text.columnize(methods))
# Out:
# agg        corr      cumsum     get_group  mean     pct_change  sem    transform
# aggregate  corrwith  describe   head       median   pipe        shift  tshift
# all        count     diff       hist       min      plot        size   var
# any        cov       expanding  idxmax     ngroup   prod        skew
# apply      cumcount  ffill      idxmin     nth      quantile    std
# backfill   cummax    fillna     last       nunique  rank        sum
# bfill      cummin    filter     mad        ohlc     resample    tail
# boxplot    cumprod   first      max        pad      rolling     take

# %%
import IPython

methods = [method_name for method_name in dir(df_group_pclass) 
           if callable(getattr(df_group_pclass, method_name)) & ~method_name.startswith('_')]

print(IPython.utils.text.columnize(methods))
# Out:
# agg        corr      cumsum     get_group  mean     pct_change  sem    transform
# aggregate  corrwith  describe   head       median   pipe        shift  tshift
# all        count     diff       hist       min      plot        size   var
# any        cov       expanding  idxmax     ngroup   prod        skew
# apply      cumcount  ffill      idxmin     nth      quantile    std
# backfill   cummax    fillna     last       nunique  rank        sum
# bfill      cummin    filter     mad        ohlc     resample    tail
# boxplot    cumprod   first      max        pad      rolling     take

# %%
df_group_pclass.

# %% [markdown]
# ## Processing

# %%
df.groupby('Sex').Age.max()
# Out:
# Sex
# female    63.0
# male      80.0
# Name: Age, dtype: float64

# %%
df_groupby_sex.Age.max()
# Out:
# Sex
# female    63.0
# male      80.0
# Name: Age, dtype: float64

# %%
df.groupby('Sex').Age.min()
# Out:
# Sex
# female    0.75
# male      0.42
# Name: Age, dtype: float64

# %%
df.groupby('Sex').Age.mean()
# Out:
# Sex
# female    27.915709
# male      30.726645
# Name: Age, dtype: float64

# %%
df.groupby('Sex').Age.median()
# Out:
# Sex
# female    27.0
# male      29.0
# Name: Age, dtype: float64

# %%
df.groupby('Sex').Name.max()
# Out:
# Sex
# female    de Messemaeker, Mrs. Guillaume Joseph (Emma)
# male                       van Melkebeke, Mr. Philemon
# Name: Name, dtype: object

# %%
df.groupby('Sex').Name.min()
# Out:
# Sex
# female    Abbott, Mrs. Stanton (Rosa Hunt)
# male                   Abbing, Mr. Anthony
# Name: Name, dtype: object

# %%
# This will not work
#df.groupby('Sex').Name.median()

# Error >>> DataError: No numeric types to aggregate

# %%
df_groupby_sex.get_group('male')['Age'].max()
# Out:
# 80.0

# %%
df_groupby_sex.get_group('female')['Age'].max()
# Out:
# 63.0

# %% [markdown]
# # Aggregating Values based on Group

# %%
df.groupby('Sex').Age.agg(['max', 'min', 'count', 'median', 'mean'])
# Out:
#          max   min  count  median       mean
# Sex
# female  63.0  0.75    261    27.0  27.915709
# male    80.0  0.42    453    29.0  30.726645

# %%
# with custom column name
df.groupby('Sex').Age.agg(
    sex_max=('max'),
    sex_min=('min'),
)
# Out:
#         sex_max  sex_min
# Sex
# female     63.0     0.75
# male       80.0     0.42

# %%
# with custom column name
df.groupby('Sex').Age.agg(
    sex_max=('max'),
    sex_min=('min'),
    total_count=('count')
)
# Out:
#         sex_max  sex_min  total_count
# Sex
# female     63.0     0.75          261
# male       80.0     0.42          453

# %%
# Custom aggregation function
def categorize(x):
    m = x.mean()
    return True if m > 29 else False

df.groupby('Sex').Age.agg(['max', 'mean', categorize])
# Out:
#          max       mean  categorize
# Sex
# female  63.0  27.915709       False
# male    80.0  30.726645        True

# %%
df_groupby_sex.get_group('male').Age.agg(['max', 'mean', categorize])
# Out:
# max                80
# mean          30.7266
# categorize       True
# Name: Age, dtype: object

# %%
df_groupby_sex.get_group('female').Age.agg(['max', 'mean', categorize])
# Out:
# max                63
# mean          27.9157
# categorize      False
# Name: Age, dtype: object

# %%
df_groupby_sex.Age.agg(['max', 'mean', categorize])
# Out:
#          max       mean  categorize
# Sex
# female  63.0  27.915709       False
# male    80.0  30.726645        True

# %%
# Use lambda
df.groupby('Sex').Age.agg(
    ['max', 'mean', lambda x: True if x.mean() > 29 else False]
)
# Out:
#          max       mean  <lambda_0>
# Sex
# female  63.0  27.915709       False
# male    80.0  30.726645        True

# %%
# Use lambda
df.groupby('Sex').Age.agg(
    ['max', 'mean', lambda x: True if x.mean() > 29 else False, 'count']
)
# Out:
#          max       mean  <lambda_0>  count
# Sex
# female  63.0  27.915709       False    261
# male    80.0  30.726645        True    453

# %%
# Use lambda
df.groupby('Sex').Age.agg(
    ['max', 'mean', lambda x: True if x.mean() > 29 else False, 'count', 'min', 'median']
)
# Out:
#          max       mean  <lambda_0>  count   min  median
# Sex
# female  63.0  27.915709       False    261  0.75    27.0
# male    80.0  30.726645        True    453  0.42    29.0

# %% [markdown]
# # Applicable to full DataFrame when calling without column

# %%
df.groupby('Sex').mean()
## applicable to all numeric columns
# Out:
#         PassengerId  Survived    Pclass        Age     SibSp     Parch  \
# Sex
# female   431.028662  0.742038  2.159236  27.915709  0.694268  0.649682
# male     454.147314  0.188908  2.389948  30.726645  0.429809  0.235702
#
#              Fare
# Sex
# female  44.479818
# male    25.523893

# %%
df.groupby('Sex').median()
# Out:
#         PassengerId  Survived  Pclass   Age  SibSp  Parch  Fare
# Sex
# female        414.5       1.0     2.0  27.0    0.0    0.0  23.0
# male          464.0       0.0     3.0  29.0    0.0    0.0  10.5

# %%
# The following will not work
#df.groupby('Sex').min()
#df.groupby('Sex').max()

# %%
df.groupby('Sex').agg(['mean', 'median'])
# Out:
#        PassengerId         Survived           Pclass               Age         \
#               mean median      mean median      mean median       mean median
# Sex
# female  431.028662  414.5  0.742038      1  2.159236      2  27.915709   27.0
# male    454.147314  464.0  0.188908      0  2.389948      3  30.726645   29.0
#
#            SibSp            Parch              Fare
#             mean median      mean median       mean median
# Sex
# female  0.694268      0  0.649682      0  44.479818   23.0
# male    0.429809      0  0.235702      0  25.523893   10.5

# %% [markdown]
# # Transforming the Data with groupby

# %%
standard_deviation = lambda x: x.std()

# %%
df.groupby('Sex').Age.transform(standard_deviation)
# Out:
# 0      14.678201
# 1      14.110146
# 2      14.110146
# 3      14.110146
# 4      14.678201
#          ...
# 886    14.678201
# 887    14.110146
# 888    14.110146
# 889    14.678201
# 890    14.678201
# Name: Age, Length: 891, dtype: float64

# %%
df.groupby('Sex').Age.apply(standard_deviation)
# Out:
# Sex
# female    14.110146
# male      14.678201
# Name: Age, dtype: float64

# %%
# A lambda expression for Standardization.
standardization = lambda x: (x - x.mean()) / x.std()

# %%
df.groupby('Sex').Age.transform(standardization)
# Out:
# 0     -0.594531
# 1      0.714684
# 2     -0.135768
# 3      0.502071
# 4      0.291136
#          ...
# 886   -0.253890
# 887   -0.631865
# 888         NaN
# 889   -0.322018
# 890    0.086751
# Name: Age, Length: 891, dtype: float64

# %%
df.groupby('Sex').Age.apply(standardization)
# Out:
# 0     -0.594531
# 1      0.714684
# 2     -0.135768
# 3      0.502071
# 4      0.291136
#          ...
# 886   -0.253890
# 887   -0.631865
# 888         NaN
# 889   -0.322018
# 890    0.086751
# Name: Age, Length: 891, dtype: float64

# %% [markdown]
# # Filtering Data

# %%
# Let's group by Cabin and take a quick look at the size for each group
df.groupby('Cabin').size()
# Out:
# Cabin
# A10    1
# A14    1
# A16    1
# A19    1
# A20    1
#       ..
# F33    3
# F38    1
# F4     2
# G6     4
# T      1
# Length: 147, dtype: int64

# %%
# filter data to return all passengers that lived in a cabin has ≥ 4 people.
df.groupby('Cabin').filter(lambda x: len(x) >= 4)
# Out:
#      PassengerId  Survived  Pclass  \
# 10            11         1       3
# 27            28         0       1
# 88            89         1       1
# 205          206         0       3
# 251          252         0       3
# 341          342         1       1
# 390          391         1       1
# 394          395         1       3
# 435          436         1       1
# 438          439         0       1
# 763          764         1       1
# 802          803         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 27                      Fortune, Mr. Charles Alexander    male  19.0      3
# 88                          Fortune, Miss. Mabel Helen  female  23.0      3
# 205                         Strom, Miss. Telma Matilda  female   2.0      0
# 251         Strom, Mrs. Wilhelm (Elna Matilda Persson)  female  29.0      1
# 341                     Fortune, Miss. Alice Elizabeth  female  24.0      3
# 390                         Carter, Mr. William Ernest    male  36.0      1
# 394  Sandstrom, Mrs. Hjalmar (Agnes Charlotta Bengt...  female  24.0      0
# 435                          Carter, Miss. Lucile Polk  female  14.0      1
# 438                                  Fortune, Mr. Mark    male  64.0      1
# 763          Carter, Mrs. William Ernest (Lucile Polk)  female  36.0      1
# 802                Carter, Master. William Thornton II    male  11.0      1
#
#      Parch   Ticket      Fare        Cabin Embarked
# 10       1  PP 9549   16.7000           G6        S
# 27       2    19950  263.0000  C23 C25 C27        S
# 88       2    19950  263.0000  C23 C25 C27        S
# 205      1   347054   10.4625           G6        S
# 251      1   347054   10.4625           G6        S
# 341      2    19950  263.0000  C23 C25 C27        S
# 390      2   113760  120.0000      B96 B98        S
# 394      2  PP 9549   16.7000           G6        S
# 435      2   113760  120.0000      B96 B98        S
# 438      4    19950  263.0000  C23 C25 C27        S
# 763      2   113760  120.0000      B96 B98        S
# 802      2   113760  120.0000      B96 B98        S

# %% [markdown]
# # Group by multiple categories

# %%
# Creating a subset
subset = df.loc[:, ['Sex', 'Pclass', 'Age', 'Fare']]

# %%
subset
# Out:
#         Sex  Pclass   Age     Fare
# 0      male       3  22.0   7.2500
# 1    female       1  38.0  71.2833
# 2    female       3  26.0   7.9250
# 3    female       1  35.0  53.1000
# 4      male       3  35.0   8.0500
# ..      ...     ...   ...      ...
# 886    male       2  27.0  13.0000
# 887  female       1  19.0  30.0000
# 888  female       3   NaN  23.4500
# 889    male       1  26.0  30.0000
# 890    male       3  32.0   7.7500
#
# [891 rows x 4 columns]

# %%
# Grouping by multiple categories
subset.groupby(['Sex', 'Pclass']).mean()
# Out:
#                      Age        Fare
# Sex    Pclass
# female 1       34.611765  106.125798
#        2       28.722973   21.970121
#        3       21.750000   16.118810
# male   1       41.281386   67.226127
#        2       30.740707   19.741782
#        3       26.507589   12.661633

# %%
# Creating a subset
subset_5 = df.loc[:, ['Sex', 'Pclass', 'Survived', 'Age', 'Fare']]

# %%
subset_5.shape
# Out:
# (891, 5)

# %%
subset_5
# Out:
#         Sex  Pclass  Survived   Age     Fare
# 0      male       3         0  22.0   7.2500
# 1    female       1         1  38.0  71.2833
# 2    female       3         1  26.0   7.9250
# 3    female       1         1  35.0  53.1000
# 4      male       3         0  35.0   8.0500
# ..      ...     ...       ...   ...      ...
# 886    male       2         0  27.0  13.0000
# 887  female       1         1  19.0  30.0000
# 888  female       3         0   NaN  23.4500
# 889    male       1         1  26.0  30.0000
# 890    male       3         0  32.0   7.7500
#
# [891 rows x 5 columns]

# %%
# Grouping by multiple categories
subset_5.groupby(['Sex', 'Pclass', 'Survived']).mean()
# Out:
#                               Age        Fare
# Sex    Pclass Survived
# female 1      0         25.666667  110.604167
#               1         34.939024  105.978159
#        2      0         36.000000   18.250000
#               1         28.080882   22.288989
#        3      0         23.818182   19.773093
#               1         19.329787   12.464526
# male   1      0         44.581967   62.894910
#               1         36.248000   74.637320
#        2      0         33.369048   19.488965
#               1         16.022000   21.095100
#        3      0         27.255814   12.204469
#               1         22.274211   15.579696

# %%
subset_5.groupby(by=['Sex', 'Pclass', 'Survived']).mean()
# Out:
#                               Age        Fare
# Sex    Pclass Survived
# female 1      0         25.666667  110.604167
#               1         34.939024  105.978159
#        2      0         36.000000   18.250000
#               1         28.080882   22.288989
#        3      0         23.818182   19.773093
#               1         19.329787   12.464526
# male   1      0         44.581967   62.894910
#               1         36.248000   74.637320
#        2      0         33.369048   19.488965
#               1         16.022000   21.095100
#        3      0         27.255814   12.204469
#               1         22.274211   15.579696

# %%
df_subset_5 = subset_5.groupby(['Sex', 'Pclass', 'Survived']).mean()

# %%
df_subset_5
# Out:
#                               Age        Fare
# Sex    Pclass Survived
# female 1      0         25.666667  110.604167
#               1         34.939024  105.978159
#        2      0         36.000000   18.250000
#               1         28.080882   22.288989
#        3      0         23.818182   19.773093
#               1         19.329787   12.464526
# male   1      0         44.581967   62.894910
#               1         36.248000   74.637320
#        2      0         33.369048   19.488965
#               1         16.022000   21.095100
#        3      0         27.255814   12.204469
#               1         22.274211   15.579696

# %%
type(df_subset_5)
# Out:
# pandas.core.frame.DataFrame

# %%
df_subset_5.shape
# Out:
# (12, 2)

# %%
subset_5.shape
# Out:
# (891, 5)

# %%
df_subset_5.reset_index()
# Out:
#        Sex  Pclass  Survived        Age        Fare
# 0   female       1         0  25.666667  110.604167
# 1   female       1         1  34.939024  105.978159
# 2   female       2         0  36.000000   18.250000
# 3   female       2         1  28.080882   22.288989
# 4   female       3         0  23.818182   19.773093
# 5   female       3         1  19.329787   12.464526
# 6     male       1         0  44.581967   62.894910
# 7     male       1         1  36.248000   74.637320
# 8     male       2         0  33.369048   19.488965
# 9     male       2         1  16.022000   21.095100
# 10    male       3         0  27.255814   12.204469
# 11    male       3         1  22.274211   15.579696

# %%
# A better way is to set as_index=False
subset_5.groupby(by=['Sex', 'Pclass', 'Survived'], as_index=False).mean()
# Out:
#        Sex  Pclass  Survived        Age        Fare
# 0   female       1         0  25.666667  110.604167
# 1   female       1         1  34.939024  105.978159
# 2   female       2         0  36.000000   18.250000
# 3   female       2         1  28.080882   22.288989
# 4   female       3         0  23.818182   19.773093
# 5   female       3         1  19.329787   12.464526
# 6     male       1         0  44.581967   62.894910
# 7     male       1         1  36.248000   74.637320
# 8     male       2         0  33.369048   19.488965
# 9     male       2         1  16.022000   21.095100
# 10    male       3         0  27.255814   12.204469
# 11    male       3         1  22.274211   15.579696

# %% [markdown]
# # Handling missing values

# %%
subset_5
# Out:
#         Sex  Pclass  Survived   Age     Fare
# 0      male       3         0  22.0   7.2500
# 1    female       1         1  38.0  71.2833
# 2    female       3         1  26.0   7.9250
# 3    female       1         1  35.0  53.1000
# 4      male       3         0  35.0   8.0500
# ..      ...     ...       ...   ...      ...
# 886    male       2         0  27.0  13.0000
# 887  female       1         1  19.0  30.0000
# 888  female       3         0   NaN  23.4500
# 889    male       1         1  26.0  30.0000
# 890    male       3         0  32.0   7.7500
#
# [891 rows x 5 columns]

# %%
subset_5.head()
# Out:
#       Sex  Pclass  Survived   Age     Fare
# 0    male       3         0  22.0   7.2500
# 1  female       1         1  38.0  71.2833
# 2  female       3         1  26.0   7.9250
# 3  female       1         1  35.0  53.1000
# 4    male       3         0  35.0   8.0500

# %%
subset_5.isna().sum()
# Out:
# Sex           0
# Pclass        0
# Survived      0
# Age         177
# Fare          0
# dtype: int64

# %%
subset_5.shape
# Out:
# (891, 5)

# %%
# Create some missing values in Sex column
subset_5.iloc[100:200, 0] = np.nan

# %%
subset_5.isna().sum()
# Out:
# Sex         100
# Pclass        0
# Survived      0
# Age         177
# Fare          0
# dtype: int64

# %%
# The groupby function ignores the missing values by default.
subset_5.groupby(['Sex', 'Pclass', 'Survived']).mean()
# Out:
#                               Age        Fare
# Sex    Pclass Survived
# female 1      0         13.500000  151.550000
#               1         34.897436  108.394042
#        2      0         38.400000   19.300000
#               1         27.750000   22.613321
#        3      0         23.989362   19.099735
#               1         20.037500   12.257243
# male   1      0         45.086538   61.439580
#               1         36.023590   75.730214
#        2      0         34.125000   18.975054
#               1         18.179231   19.574447
#        3      0         26.895722   11.960256
#               1         22.777059   16.137298

# %%
subset_5.groupby(by=['Sex', 'Pclass', 'Survived'],  dropna=False).mean()

# An issue with 
# https://github.com/pandas-dev/pandas/issues/37323
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-132-362a3e9c4b1f> in <module>
# ----> 1 subset_5.groupby(by=['Sex', 'Pclass', 'Survived'],  dropna=False).mean()
#       2
#       3 # An issue with
#       4 # https://github.com/pandas-dev/pandas/issues/37323
#
# TypeError: groupby() got an unexpected keyword argument 'dropna'

# %% [markdown]
# # Creating Graph

# %%
# %matplotlib inline

# %%
subset_5.groupby('Sex').mean().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Sex'>

# %%
subset_5.groupby('Sex').get_group('male').mean().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
subset_5.groupby('Sex').get_group('female').mean().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
subset_5.groupby('Pclass').mean().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Pclass'>

# %%
subset_5.groupby('Survived').mean().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Survived'>

# %%
df.groupby('Cabin').plot(kind='bar')
# Out:
# /Users/avkash/anaconda3/lib/python3.7/site-packages/pandas/plotting/_matplotlib/core.py:320: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# Cabin
# A10    AxesSubplot(0.125,0.125;0.775x0.755)
# A14    AxesSubplot(0.125,0.125;0.775x0.755)
# A16    AxesSubplot(0.125,0.125;0.775x0.755)
# A19    AxesSubplot(0.125,0.125;0.775x0.755)
# A20    AxesSubplot(0.125,0.125;0.775x0.755)
#                        ...
# F33    AxesSubplot(0.125,0.125;0.775x0.755)
# F38    AxesSubplot(0.125,0.125;0.775x0.755)
# F4     AxesSubplot(0.125,0.125;0.775x0.755)
# G6     AxesSubplot(0.125,0.125;0.775x0.755)
# T      AxesSubplot(0.125,0.125;0.775x0.755)
# Length: 147, dtype: object

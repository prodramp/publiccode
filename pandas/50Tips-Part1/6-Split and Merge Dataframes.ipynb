# %%
import pandas as pd

# %%
# !ls ../../datasets
# Out:
# titanic.csv     titanic.csv.zip

# %%
local_source = '../../datasets/titanic.csv'
df = pd.read_csv(local_source)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %% [markdown]
# # 6.1 Spliting data into other data frames based on column values (Keeping the same headers) - Horizontal Split

# %%
df_male = df[df['Sex'] == 'male']

# %%
df_male
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# ..           ...       ...     ...                             ...   ...
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 889          890         1       1           Behr, Mr. Karl Howell  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0    22.0      1      0         A/5 21171   7.2500   NaN        S
# 4    35.0      0      0            373450   8.0500   NaN        S
# 5     NaN      0      0            330877   8.4583   NaN        Q
# 6    54.0      0      0             17463  51.8625   E46        S
# 7     2.0      3      1            349909  21.0750   NaN        S
# ..    ...    ...    ...               ...      ...   ...      ...
# 883  28.0      0      0  C.A./SOTON 34068  10.5000   NaN        S
# 884  25.0      0      0   SOTON/OQ 392076   7.0500   NaN        S
# 886  27.0      0      0            211536  13.0000   NaN        S
# 889  26.0      0      0            111369  30.0000  C148        C
# 890  32.0      0      0            370376   7.7500   NaN        Q
#
# [577 rows x 12 columns]

# %%
df_female = df[df['Sex'] == 'female']

# %%
df_female
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 880          881         1       2
# 882          883         0       3
# 885          886         0       3
# 887          888         1       1
# 888          889         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# 880       Shelley, Mrs. William (Imanita Parrish Hall)  female  25.0      0
# 882                       Dahlberg, Miss. Gerda Ulrika  female  22.0      0
# 885               Rice, Mrs. William (Margaret Norton)  female  39.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
#
#      Parch            Ticket     Fare Cabin Embarked
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 8        2            347742  11.1333   NaN        S
# 9        0            237736  30.0708   NaN        C
# ..     ...               ...      ...   ...      ...
# 880      1            230433  26.0000   NaN        S
# 882      0              7552  10.5167   NaN        S
# 885      5            382652  29.1250   NaN        Q
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
#
# [314 rows x 12 columns]

# %% [markdown]
# # 6.2 Spliting data into other data frames based on column values and selecting few columns - Vertical Split

# %%
df_split_4_columns = df[['Name', 'Sex','Age', 'Ticket']]

# %%
df_split_4_columns
# Out:
#                                                   Name     Sex   Age  \
# 0                              Braund, Mr. Owen Harris    male  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                               Heikkinen, Miss. Laina  female  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                             Allen, Mr. William Henry    male  35.0
# ..                                                 ...     ...   ...
# 886                              Montvila, Rev. Juozas    male  27.0
# 887                       Graham, Miss. Margaret Edith  female  19.0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 889                              Behr, Mr. Karl Howell    male  26.0
# 890                                Dooley, Mr. Patrick    male  32.0
#
#                Ticket
# 0           A/5 21171
# 1            PC 17599
# 2    STON/O2. 3101282
# 3              113803
# 4              373450
# ..                ...
# 886            211536
# 887            112053
# 888        W./C. 6607
# 889            111369
# 890            370376
#
# [891 rows x 4 columns]

# %%
df_split_8_columns = df[['Name', 'Survived', 'Pclass','SibSp', 'Parch', 'Fare', 'Cabin', 'Embarked']]

# %%
df_split_8_columns
# Out:
#                                                   Name  Survived  Pclass  \
# 0                              Braund, Mr. Owen Harris         0       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                               Heikkinen, Miss. Laina         1       3
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1
# 4                             Allen, Mr. William Henry         0       3
# ..                                                 ...       ...     ...
# 886                              Montvila, Rev. Juozas         0       2
# 887                       Graham, Miss. Margaret Edith         1       1
# 888           Johnston, Miss. Catherine Helen "Carrie"         0       3
# 889                              Behr, Mr. Karl Howell         1       1
# 890                                Dooley, Mr. Patrick         0       3
#
#      SibSp  Parch     Fare Cabin Embarked
# 0        1      0   7.2500   NaN        S
# 1        1      0  71.2833   C85        C
# 2        0      0   7.9250   NaN        S
# 3        1      0  53.1000  C123        S
# 4        0      0   8.0500   NaN        S
# ..     ...    ...      ...   ...      ...
# 886      0      0  13.0000   NaN        S
# 887      0      0  30.0000   B42        S
# 888      1      2  23.4500   NaN        S
# 889      0      0  30.0000  C148        C
# 890      0      0   7.7500   NaN        Q
#
# [891 rows x 8 columns]

# %% [markdown]
# # 6.3 Pandas Concat - Combine Rows with the same header

# %% [markdown]
# pandas.concat(objs, axis=0, join='outer', ignore_index=False, keys=None,
#               levels=None, names=None, verify_integrity=False, sort=False, copy=True)
#
# - objs is the list of DataFrame objects ([df1, df2, ...]) to be concatenated
# - axis defines the direction of the concatenation, 0 for row-wise and 1 for column-wise
# - join can either be inner (intersection) or outer (union)

# %% [markdown]
# ### we already have df_male and df_female data frames with the exact same header

# %%
df_mix_sex = pd.concat([df_female, df_male])

# %%
df_mix_sex
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 883          884         0       2
# 884          885         0       3
# 886          887         0       2
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# 883                      Banfield, Mr. Frederick James    male  28.0      0
# 884                             Sutehall, Mr. Henry Jr    male  25.0      0
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 8        2            347742  11.1333   NaN        S
# 9        0            237736  30.0708   NaN        C
# ..     ...               ...      ...   ...      ...
# 883      0  C.A./SOTON 34068  10.5000   NaN        S
# 884      0   SOTON/OQ 392076   7.0500   NaN        S
# 886      0            211536  13.0000   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
df_mix_sex = pd.concat([df_female, df_male]).reset_index(drop = True)

# %%
df_mix_sex
# Out:
#      PassengerId  Survived  Pclass  \
# 0              2         1       1
# 1              3         1       3
# 2              4         1       1
# 3              9         1       3
# 4             10         1       2
# ..           ...       ...     ...
# 886          884         0       2
# 887          885         0       3
# 888          887         0       2
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 1                               Heikkinen, Miss. Laina  female  26.0      0
# 2         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 3    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 4                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# 886                      Banfield, Mr. Frederick James    male  28.0      0
# 887                             Sutehall, Mr. Henry Jr    male  25.0      0
# 888                              Montvila, Rev. Juozas    male  27.0      0
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0          PC 17599  71.2833   C85        C
# 1        0  STON/O2. 3101282   7.9250   NaN        S
# 2        0            113803  53.1000  C123        S
# 3        2            347742  11.1333   NaN        S
# 4        0            237736  30.0708   NaN        C
# ..     ...               ...      ...   ...      ...
# 886      0  C.A./SOTON 34068  10.5000   NaN        S
# 887      0   SOTON/OQ 392076   7.0500   NaN        S
# 888      0            211536  13.0000   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
df_male.shape
# Out:
# (577, 12)

# %%
df_female.shape
# Out:
# (314, 12)

# %%
pd.concat([df_male, df_female],ignore_index=True)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              5         0       3
# 2              6         0       3
# 3              7         0       1
# 4              8         0       3
# ..           ...       ...     ...
# 886          881         1       2
# 887          883         0       3
# 888          886         0       3
# 889          888         1       1
# 890          889         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                         Braund, Mr. Owen Harris    male  22.0      1      0
# 1                        Allen, Mr. William Henry    male  35.0      0      0
# 2                                Moran, Mr. James    male   NaN      0      0
# 3                         McCarthy, Mr. Timothy J    male  54.0      0      0
# 4                  Palsson, Master. Gosta Leonard    male   2.0      3      1
# ..                                            ...     ...   ...    ...    ...
# 886  Shelley, Mrs. William (Imanita Parrish Hall)  female  25.0      0      1
# 887                  Dahlberg, Miss. Gerda Ulrika  female  22.0      0      0
# 888          Rice, Mrs. William (Margaret Norton)  female  39.0      0      5
# 889                  Graham, Miss. Margaret Edith  female  19.0      0      0
# 890      Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1      2
#
#          Ticket     Fare Cabin Embarked
# 0     A/5 21171   7.2500   NaN        S
# 1        373450   8.0500   NaN        S
# 2        330877   8.4583   NaN        Q
# 3         17463  51.8625   E46        S
# 4        349909  21.0750   NaN        S
# ..          ...      ...   ...      ...
# 886      230433  26.0000   NaN        S
# 887        7552  10.5167   NaN        S
# 888      382652  29.1250   NaN        Q
# 889      112053  30.0000   B42        S
# 890  W./C. 6607  23.4500   NaN        S
#
# [891 rows x 12 columns]

# %%
pd.concat([df_male, df_female])
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# ..           ...       ...     ...
# 880          881         1       2
# 882          883         0       3
# 885          886         0       3
# 887          888         1       1
# 888          889         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                         Braund, Mr. Owen Harris    male  22.0      1      0
# 4                        Allen, Mr. William Henry    male  35.0      0      0
# 5                                Moran, Mr. James    male   NaN      0      0
# 6                         McCarthy, Mr. Timothy J    male  54.0      0      0
# 7                  Palsson, Master. Gosta Leonard    male   2.0      3      1
# ..                                            ...     ...   ...    ...    ...
# 880  Shelley, Mrs. William (Imanita Parrish Hall)  female  25.0      0      1
# 882                  Dahlberg, Miss. Gerda Ulrika  female  22.0      0      0
# 885          Rice, Mrs. William (Margaret Norton)  female  39.0      0      5
# 887                  Graham, Miss. Margaret Edith  female  19.0      0      0
# 888      Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1      2
#
#          Ticket     Fare Cabin Embarked
# 0     A/5 21171   7.2500   NaN        S
# 4        373450   8.0500   NaN        S
# 5        330877   8.4583   NaN        Q
# 6         17463  51.8625   E46        S
# 7        349909  21.0750   NaN        S
# ..          ...      ...   ...      ...
# 880      230433  26.0000   NaN        S
# 882        7552  10.5167   NaN        S
# 885      382652  29.1250   NaN        Q
# 887      112053  30.0000   B42        S
# 888  W./C. 6607  23.4500   NaN        S
#
# [891 rows x 12 columns]

# %%
pd.concat([df_male, df_female], sort=['Ticket'])
# Out:
#       Age Cabin Embarked     Fare  \
# 0    22.0   NaN        S   7.2500
# 4    35.0   NaN        S   8.0500
# 5     NaN   NaN        Q   8.4583
# 6    54.0   E46        S  51.8625
# 7     2.0   NaN        S  21.0750
# ..    ...   ...      ...      ...
# 880  25.0   NaN        S  26.0000
# 882  22.0   NaN        S  10.5167
# 885  39.0   NaN        Q  29.1250
# 887  19.0   B42        S  30.0000
# 888   NaN   NaN        S  23.4500
#
#                                              Name  Parch  PassengerId  Pclass  \
# 0                         Braund, Mr. Owen Harris      0            1       3
# 4                        Allen, Mr. William Henry      0            5       3
# 5                                Moran, Mr. James      0            6       3
# 6                         McCarthy, Mr. Timothy J      0            7       1
# 7                  Palsson, Master. Gosta Leonard      1            8       3
# ..                                            ...    ...          ...     ...
# 880  Shelley, Mrs. William (Imanita Parrish Hall)      1          881       2
# 882                  Dahlberg, Miss. Gerda Ulrika      0          883       3
# 885          Rice, Mrs. William (Margaret Norton)      5          886       3
# 887                  Graham, Miss. Margaret Edith      0          888       1
# 888      Johnston, Miss. Catherine Helen "Carrie"      2          889       3
#
#         Sex  SibSp  Survived      Ticket
# 0      male      1         0   A/5 21171
# 4      male      0         0      373450
# 5      male      0         0      330877
# 6      male      0         0       17463
# 7      male      3         0      349909
# ..      ...    ...       ...         ...
# 880  female      0         1      230433
# 882  female      0         0        7552
# 885  female      0         0      382652
# 887  female      0         1      112053
# 888  female      1         0  W./C. 6607
#
# [891 rows x 12 columns]

# %% [markdown]
# ### Note: Pandas concat function work both horizontally and vertically.
# - To join two DataFrames together column-wise, you need to change the axis value from the default 0 to 1
# - axis : 0 (Rowwise Concat)
# - axis : 1 (Columnwide Concat)

# %% [markdown]
# # 6.4 Pandas Concat Option - Merge Columns

# %%
df_concat_left = df[['Name', 'Sex','Age', 'Ticket']]

# %%
df_concat_right = df[['Name', 'Survived', 'Pclass','SibSp', 'Parch', 'Fare', 'Cabin', 'Embarked']]

# %%
pd.concat([df_concat_left, df_concat_right], axis= 1 )
# Out:
#                                                   Name     Sex   Age  \
# 0                              Braund, Mr. Owen Harris    male  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                               Heikkinen, Miss. Laina  female  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                             Allen, Mr. William Henry    male  35.0
# ..                                                 ...     ...   ...
# 886                              Montvila, Rev. Juozas    male  27.0
# 887                       Graham, Miss. Margaret Edith  female  19.0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 889                              Behr, Mr. Karl Howell    male  26.0
# 890                                Dooley, Mr. Patrick    male  32.0
#
#                Ticket                                               Name  \
# 0           A/5 21171                            Braund, Mr. Owen Harris
# 1            PC 17599  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2    STON/O2. 3101282                             Heikkinen, Miss. Laina
# 3              113803       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              373450                           Allen, Mr. William Henry
# ..                ...                                                ...
# 886            211536                              Montvila, Rev. Juozas
# 887            112053                       Graham, Miss. Margaret Edith
# 888        W./C. 6607           Johnston, Miss. Catherine Helen "Carrie"
# 889            111369                              Behr, Mr. Karl Howell
# 890            370376                                Dooley, Mr. Patrick
#
#      Survived  Pclass  SibSp  Parch     Fare Cabin Embarked
# 0           0       3      1      0   7.2500   NaN        S
# 1           1       1      1      0  71.2833   C85        C
# 2           1       3      0      0   7.9250   NaN        S
# 3           1       1      1      0  53.1000  C123        S
# 4           0       3      0      0   8.0500   NaN        S
# ..        ...     ...    ...    ...      ...   ...      ...
# 886         0       2      0      0  13.0000   NaN        S
# 887         1       1      0      0  30.0000   B42        S
# 888         0       3      1      2  23.4500   NaN        S
# 889         1       1      0      0  30.0000  C148        C
# 890         0       3      0      0   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %% [markdown]
# # 6.5 Pandas merge Option

# %% [markdown]
# pd.merge(left, right, how='inner', on=None, left_on=None, right_on=None,
#          left_index=False, right_index=False, sort=True,
#          suffixes=('_x', '_y'), copy=True, indicator=False,
#          validate=None)

# %% [markdown]
# ## Merging with Non Indexed DataFrame

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
df_a = df[['Name', 'Sex','Age', 'Ticket']]

# %%
df_a
# Out:
#                                                   Name     Sex   Age  \
# 0                              Braund, Mr. Owen Harris    male  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                               Heikkinen, Miss. Laina  female  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                             Allen, Mr. William Henry    male  35.0
# ..                                                 ...     ...   ...
# 886                              Montvila, Rev. Juozas    male  27.0
# 887                       Graham, Miss. Margaret Edith  female  19.0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 889                              Behr, Mr. Karl Howell    male  26.0
# 890                                Dooley, Mr. Patrick    male  32.0
#
#                Ticket
# 0           A/5 21171
# 1            PC 17599
# 2    STON/O2. 3101282
# 3              113803
# 4              373450
# ..                ...
# 886            211536
# 887            112053
# 888        W./C. 6607
# 889            111369
# 890            370376
#
# [891 rows x 4 columns]

# %%
df_b = df[['Name', 'Survived', 'Pclass','SibSp', 'Parch', 'Fare', 'Cabin', 'Embarked']]

# %%
df_b
# Out:
#                                                   Name  Survived  Pclass  \
# 0                              Braund, Mr. Owen Harris         0       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                               Heikkinen, Miss. Laina         1       3
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1
# 4                             Allen, Mr. William Henry         0       3
# ..                                                 ...       ...     ...
# 886                              Montvila, Rev. Juozas         0       2
# 887                       Graham, Miss. Margaret Edith         1       1
# 888           Johnston, Miss. Catherine Helen "Carrie"         0       3
# 889                              Behr, Mr. Karl Howell         1       1
# 890                                Dooley, Mr. Patrick         0       3
#
#      SibSp  Parch     Fare Cabin Embarked
# 0        1      0   7.2500   NaN        S
# 1        1      0  71.2833   C85        C
# 2        0      0   7.9250   NaN        S
# 3        1      0  53.1000  C123        S
# 4        0      0   8.0500   NaN        S
# ..     ...    ...      ...   ...      ...
# 886      0      0  13.0000   NaN        S
# 887      0      0  30.0000   B42        S
# 888      1      2  23.4500   NaN        S
# 889      0      0  30.0000  C148        C
# 890      0      0   7.7500   NaN        Q
#
# [891 rows x 8 columns]

# %%
df_merged_non_index = pd.merge(df_a, df_b)

# %%
df_merged_non_index
# Out:
#                                                   Name     Sex   Age  \
# 0                              Braund, Mr. Owen Harris    male  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                               Heikkinen, Miss. Laina  female  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                             Allen, Mr. William Henry    male  35.0
# ..                                                 ...     ...   ...
# 886                              Montvila, Rev. Juozas    male  27.0
# 887                       Graham, Miss. Margaret Edith  female  19.0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 889                              Behr, Mr. Karl Howell    male  26.0
# 890                                Dooley, Mr. Patrick    male  32.0
#
#                Ticket  Survived  Pclass  SibSp  Parch     Fare Cabin Embarked
# 0           A/5 21171         0       3      1      0   7.2500   NaN        S
# 1            PC 17599         1       1      1      0  71.2833   C85        C
# 2    STON/O2. 3101282         1       3      0      0   7.9250   NaN        S
# 3              113803         1       1      1      0  53.1000  C123        S
# 4              373450         0       3      0      0   8.0500   NaN        S
# ..                ...       ...     ...    ...    ...      ...   ...      ...
# 886            211536         0       2      0      0  13.0000   NaN        S
# 887            112053         1       1      0      0  30.0000   B42        S
# 888        W./C. 6607         0       3      1      2  23.4500   NaN        S
# 889            111369         1       1      0      0  30.0000  C148        C
# 890            370376         0       3      0      0   7.7500   NaN        Q
#
# [891 rows x 11 columns]

# %% [markdown]
# ## Merging with Indexed DataFrame

# %%
df_indexed = pd.read_csv(local_source, index_col= 'PassengerId')

# %%
df_indexed
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# 887                                      Montvila, Rev. Juozas    male  27.0
# 888                               Graham, Miss. Margaret Edith  female  19.0
# 889                   Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 890                                      Behr, Mr. Karl Howell    male  26.0
# 891                                        Dooley, Mr. Patrick    male  32.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S
# ...            ...    ...               ...      ...   ...      ...
# 887              0      0            211536  13.0000   NaN        S
# 888              0      0            112053  30.0000   B42        S
# 889              1      2        W./C. 6607  23.4500   NaN        S
# 890              0      0            111369  30.0000  C148        C
# 891              0      0            370376   7.7500   NaN        Q
#
# [891 rows x 11 columns]

# %%
df_part_1 = df_indexed[['Survived', 'Pclass','SibSp', 'Parch', 'Fare', 'Cabin', 'Embarked']]

# %%
df_part_1
# Out:
#              Survived  Pclass  SibSp  Parch     Fare Cabin Embarked
# PassengerId
# 1                   0       3      1      0   7.2500   NaN        S
# 2                   1       1      1      0  71.2833   C85        C
# 3                   1       3      0      0   7.9250   NaN        S
# 4                   1       1      1      0  53.1000  C123        S
# 5                   0       3      0      0   8.0500   NaN        S
# ...               ...     ...    ...    ...      ...   ...      ...
# 887                 0       2      0      0  13.0000   NaN        S
# 888                 1       1      0      0  30.0000   B42        S
# 889                 0       3      1      2  23.4500   NaN        S
# 890                 1       1      0      0  30.0000  C148        C
# 891                 0       3      0      0   7.7500   NaN        Q
#
# [891 rows x 7 columns]

# %%
df_part_2 = df_indexed[['Name', 'Sex','Age', 'Ticket']]

# %%
df_part_2
# Out:
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# 887                                      Montvila, Rev. Juozas    male  27.0
# 888                               Graham, Miss. Margaret Edith  female  19.0
# 889                   Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 890                                      Behr, Mr. Karl Howell    male  26.0
# 891                                        Dooley, Mr. Patrick    male  32.0
#
#                        Ticket
# PassengerId
# 1                   A/5 21171
# 2                    PC 17599
# 3            STON/O2. 3101282
# 4                      113803
# 5                      373450
# ...                       ...
# 887                    211536
# 888                    112053
# 889                W./C. 6607
# 890                    111369
# 891                    370376
#
# [891 rows x 4 columns]

# %%
df_merged = pd.merge(df_part_1, df_part_2, left_index=True, right_index=True)

# %%
df_merged
# Out:
#              Survived  Pclass  SibSp  Parch     Fare Cabin Embarked  \
# PassengerId
# 1                   0       3      1      0   7.2500   NaN        S
# 2                   1       1      1      0  71.2833   C85        C
# 3                   1       3      0      0   7.9250   NaN        S
# 4                   1       1      1      0  53.1000  C123        S
# 5                   0       3      0      0   8.0500   NaN        S
# ...               ...     ...    ...    ...      ...   ...      ...
# 887                 0       2      0      0  13.0000   NaN        S
# 888                 1       1      0      0  30.0000   B42        S
# 889                 0       3      1      2  23.4500   NaN        S
# 890                 1       1      0      0  30.0000  C148        C
# 891                 0       3      0      0   7.7500   NaN        Q
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# 887                                      Montvila, Rev. Juozas    male  27.0
# 888                               Graham, Miss. Margaret Edith  female  19.0
# 889                   Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 890                                      Behr, Mr. Karl Howell    male  26.0
# 891                                        Dooley, Mr. Patrick    male  32.0
#
#                        Ticket
# PassengerId
# 1                   A/5 21171
# 2                    PC 17599
# 3            STON/O2. 3101282
# 4                      113803
# 5                      373450
# ...                       ...
# 887                    211536
# 888                    112053
# 889                W./C. 6607
# 890                    111369
# 891                    370376
#
# [891 rows x 11 columns]

# %%
df_merged = pd.merge(df_female, df_male)

# %%
df_merged
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %% [markdown]
# # 6.6 Pandas Join method to combine two DataFrames

# %% [markdown]
# DataFrame.join(other, on=None, how='left', lsuffix='', rsuffix='', sort=False).

# %%
df_joined_left = df_part_1.join(df_part_2)

# %%
df_joined_left
# Out:
#              Survived  Pclass  SibSp  Parch     Fare Cabin Embarked  \
# PassengerId
# 1                   0       3      1      0   7.2500   NaN        S
# 2                   1       1      1      0  71.2833   C85        C
# 3                   1       3      0      0   7.9250   NaN        S
# 4                   1       1      1      0  53.1000  C123        S
# 5                   0       3      0      0   8.0500   NaN        S
# ...               ...     ...    ...    ...      ...   ...      ...
# 887                 0       2      0      0  13.0000   NaN        S
# 888                 1       1      0      0  30.0000   B42        S
# 889                 0       3      1      2  23.4500   NaN        S
# 890                 1       1      0      0  30.0000  C148        C
# 891                 0       3      0      0   7.7500   NaN        Q
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# 887                                      Montvila, Rev. Juozas    male  27.0
# 888                               Graham, Miss. Margaret Edith  female  19.0
# 889                   Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 890                                      Behr, Mr. Karl Howell    male  26.0
# 891                                        Dooley, Mr. Patrick    male  32.0
#
#                        Ticket
# PassengerId
# 1                   A/5 21171
# 2                    PC 17599
# 3            STON/O2. 3101282
# 4                      113803
# 5                      373450
# ...                       ...
# 887                    211536
# 888                    112053
# 889                W./C. 6607
# 890                    111369
# 891                    370376
#
# [891 rows x 11 columns]

# %%
df_joined_right = df_part_1.join(df_part_2, how = "right")

# %%
df_joined_right
# Out:
#              Survived  Pclass  SibSp  Parch     Fare Cabin Embarked  \
# PassengerId
# 1                   0       3      1      0   7.2500   NaN        S
# 2                   1       1      1      0  71.2833   C85        C
# 3                   1       3      0      0   7.9250   NaN        S
# 4                   1       1      1      0  53.1000  C123        S
# 5                   0       3      0      0   8.0500   NaN        S
# ...               ...     ...    ...    ...      ...   ...      ...
# 887                 0       2      0      0  13.0000   NaN        S
# 888                 1       1      0      0  30.0000   B42        S
# 889                 0       3      1      2  23.4500   NaN        S
# 890                 1       1      0      0  30.0000  C148        C
# 891                 0       3      0      0   7.7500   NaN        Q
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# 887                                      Montvila, Rev. Juozas    male  27.0
# 888                               Graham, Miss. Margaret Edith  female  19.0
# 889                   Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 890                                      Behr, Mr. Karl Howell    male  26.0
# 891                                        Dooley, Mr. Patrick    male  32.0
#
#                        Ticket
# PassengerId
# 1                   A/5 21171
# 2                    PC 17599
# 3            STON/O2. 3101282
# 4                      113803
# 5                      373450
# ...                       ...
# 887                    211536
# 888                    112053
# 889                W./C. 6607
# 890                    111369
# 891                    370376
#
# [891 rows x 11 columns]

# %%
df_joined_left = df_part_1.join(df_part_2, how = "left")

# %%
df_joined_left
# Out:
#              Survived  Pclass  SibSp  Parch     Fare Cabin Embarked  \
# PassengerId
# 1                   0       3      1      0   7.2500   NaN        S
# 2                   1       1      1      0  71.2833   C85        C
# 3                   1       3      0      0   7.9250   NaN        S
# 4                   1       1      1      0  53.1000  C123        S
# 5                   0       3      0      0   8.0500   NaN        S
# ...               ...     ...    ...    ...      ...   ...      ...
# 887                 0       2      0      0  13.0000   NaN        S
# 888                 1       1      0      0  30.0000   B42        S
# 889                 0       3      1      2  23.4500   NaN        S
# 890                 1       1      0      0  30.0000  C148        C
# 891                 0       3      0      0   7.7500   NaN        Q
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# 887                                      Montvila, Rev. Juozas    male  27.0
# 888                               Graham, Miss. Margaret Edith  female  19.0
# 889                   Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 890                                      Behr, Mr. Karl Howell    male  26.0
# 891                                        Dooley, Mr. Patrick    male  32.0
#
#                        Ticket
# PassengerId
# 1                   A/5 21171
# 2                    PC 17599
# 3            STON/O2. 3101282
# 4                      113803
# 5                      373450
# ...                       ...
# 887                    211536
# 888                    112053
# 889                W./C. 6607
# 890                    111369
# 891                    370376
#
# [891 rows x 11 columns]

# %% [markdown]
# # 6.7 Pandas Append method to combine two DataFrames

# %% [markdown]
# Append command is applicable to DataFrame and very useful to merge two DataFrames based on row axis where the headers are same between two dataframes

# %%
df_male
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# ..           ...       ...     ...                             ...   ...
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 889          890         1       1           Behr, Mr. Karl Howell  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0    22.0      1      0         A/5 21171   7.2500   NaN        S
# 4    35.0      0      0            373450   8.0500   NaN        S
# 5     NaN      0      0            330877   8.4583   NaN        Q
# 6    54.0      0      0             17463  51.8625   E46        S
# 7     2.0      3      1            349909  21.0750   NaN        S
# ..    ...    ...    ...               ...      ...   ...      ...
# 883  28.0      0      0  C.A./SOTON 34068  10.5000   NaN        S
# 884  25.0      0      0   SOTON/OQ 392076   7.0500   NaN        S
# 886  27.0      0      0            211536  13.0000   NaN        S
# 889  26.0      0      0            111369  30.0000  C148        C
# 890  32.0      0      0            370376   7.7500   NaN        Q
#
# [577 rows x 12 columns]

# %%
df_female
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 880          881         1       2
# 882          883         0       3
# 885          886         0       3
# 887          888         1       1
# 888          889         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# 880       Shelley, Mrs. William (Imanita Parrish Hall)  female  25.0      0
# 882                       Dahlberg, Miss. Gerda Ulrika  female  22.0      0
# 885               Rice, Mrs. William (Margaret Norton)  female  39.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
#
#      Parch            Ticket     Fare Cabin Embarked
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 8        2            347742  11.1333   NaN        S
# 9        0            237736  30.0708   NaN        C
# ..     ...               ...      ...   ...      ...
# 880      1            230433  26.0000   NaN        S
# 882      0              7552  10.5167   NaN        S
# 885      5            382652  29.1250   NaN        Q
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
#
# [314 rows x 12 columns]

# %%
df_male_female_appended = df_male.append(df_female)

# %%
df_male_female_appended
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# ..           ...       ...     ...
# 880          881         1       2
# 882          883         0       3
# 885          886         0       3
# 887          888         1       1
# 888          889         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                         Braund, Mr. Owen Harris    male  22.0      1      0
# 4                        Allen, Mr. William Henry    male  35.0      0      0
# 5                                Moran, Mr. James    male   NaN      0      0
# 6                         McCarthy, Mr. Timothy J    male  54.0      0      0
# 7                  Palsson, Master. Gosta Leonard    male   2.0      3      1
# ..                                            ...     ...   ...    ...    ...
# 880  Shelley, Mrs. William (Imanita Parrish Hall)  female  25.0      0      1
# 882                  Dahlberg, Miss. Gerda Ulrika  female  22.0      0      0
# 885          Rice, Mrs. William (Margaret Norton)  female  39.0      0      5
# 887                  Graham, Miss. Margaret Edith  female  19.0      0      0
# 888      Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1      2
#
#          Ticket     Fare Cabin Embarked
# 0     A/5 21171   7.2500   NaN        S
# 4        373450   8.0500   NaN        S
# 5        330877   8.4583   NaN        Q
# 6         17463  51.8625   E46        S
# 7        349909  21.0750   NaN        S
# ..          ...      ...   ...      ...
# 880      230433  26.0000   NaN        S
# 882        7552  10.5167   NaN        S
# 885      382652  29.1250   NaN        Q
# 887      112053  30.0000   B42        S
# 888  W./C. 6607  23.4500   NaN        S
#
# [891 rows x 12 columns]

# %%
df_male

# %%
df_male_local = df_male

# %%
df_male_local.append(df_female)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# ..           ...       ...     ...
# 880          881         1       2
# 882          883         0       3
# 885          886         0       3
# 887          888         1       1
# 888          889         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                         Braund, Mr. Owen Harris    male  22.0      1      0
# 4                        Allen, Mr. William Henry    male  35.0      0      0
# 5                                Moran, Mr. James    male   NaN      0      0
# 6                         McCarthy, Mr. Timothy J    male  54.0      0      0
# 7                  Palsson, Master. Gosta Leonard    male   2.0      3      1
# ..                                            ...     ...   ...    ...    ...
# 880  Shelley, Mrs. William (Imanita Parrish Hall)  female  25.0      0      1
# 882                  Dahlberg, Miss. Gerda Ulrika  female  22.0      0      0
# 885          Rice, Mrs. William (Margaret Norton)  female  39.0      0      5
# 887                  Graham, Miss. Margaret Edith  female  19.0      0      0
# 888      Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1      2
#
#          Ticket     Fare Cabin Embarked
# 0     A/5 21171   7.2500   NaN        S
# 4        373450   8.0500   NaN        S
# 5        330877   8.4583   NaN        Q
# 6         17463  51.8625   E46        S
# 7        349909  21.0750   NaN        S
# ..          ...      ...   ...      ...
# 880      230433  26.0000   NaN        S
# 882        7552  10.5167   NaN        S
# 885      382652  29.1250   NaN        Q
# 887      112053  30.0000   B42        S
# 888  W./C. 6607  23.4500   NaN        S
#
# [891 rows x 12 columns]

# %%
df_male_local
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# ..           ...       ...     ...                             ...   ...
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 889          890         1       1           Behr, Mr. Karl Howell  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0    22.0      1      0         A/5 21171   7.2500   NaN        S
# 4    35.0      0      0            373450   8.0500   NaN        S
# 5     NaN      0      0            330877   8.4583   NaN        Q
# 6    54.0      0      0             17463  51.8625   E46        S
# 7     2.0      3      1            349909  21.0750   NaN        S
# ..    ...    ...    ...               ...      ...   ...      ...
# 883  28.0      0      0  C.A./SOTON 34068  10.5000   NaN        S
# 884  25.0      0      0   SOTON/OQ 392076   7.0500   NaN        S
# 886  27.0      0      0            211536  13.0000   NaN        S
# 889  26.0      0      0            111369  30.0000  C148        C
# 890  32.0      0      0            370376   7.7500   NaN        Q
#
# [577 rows x 12 columns]

# %% [markdown]
# ### Note:
# - When append() is applied, it will not match DataFrames on any keys.
# - The result does not update the actuall DataFrame instead return a result in new data frame
# - If DataFrames shape do not match, all unmatched cells will be replaced by NaN value

# %% [markdown]
# # 6.8 Pandas Update method to combine two DataFrames

# %% [markdown]
# ### Note:
# - Update function does the inplace data update in the dataframe where it is called
# - It does not add a new rows, instead just update the data in the matched rows
# - If there is no matching data in second dataframe, the first dataframe will not change

# %%
df_male
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# ..           ...       ...     ...                             ...   ...
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 889          890         1       1           Behr, Mr. Karl Howell  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0    22.0      1      0         A/5 21171   7.2500   NaN        S
# 4    35.0      0      0            373450   8.0500   NaN        S
# 5     NaN      0      0            330877   8.4583   NaN        Q
# 6    54.0      0      0             17463  51.8625   E46        S
# 7     2.0      3      1            349909  21.0750   NaN        S
# ..    ...    ...    ...               ...      ...   ...      ...
# 883  28.0      0      0  C.A./SOTON 34068  10.5000   NaN        S
# 884  25.0      0      0   SOTON/OQ 392076   7.0500   NaN        S
# 886  27.0      0      0            211536  13.0000   NaN        S
# 889  26.0      0      0            111369  30.0000  C148        C
# 890  32.0      0      0            370376   7.7500   NaN        Q
#
# [577 rows x 12 columns]

# %%
df_female
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 880          881         1       2
# 882          883         0       3
# 885          886         0       3
# 887          888         1       1
# 888          889         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# 880       Shelley, Mrs. William (Imanita Parrish Hall)  female  25.0      0
# 882                       Dahlberg, Miss. Gerda Ulrika  female  22.0      0
# 885               Rice, Mrs. William (Margaret Norton)  female  39.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
#
#      Parch            Ticket     Fare Cabin Embarked
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 8        2            347742  11.1333   NaN        S
# 9        0            237736  30.0708   NaN        C
# ..     ...               ...      ...   ...      ...
# 880      1            230433  26.0000   NaN        S
# 882      0              7552  10.5167   NaN        S
# 885      5            382652  29.1250   NaN        Q
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
#
# [314 rows x 12 columns]

# %%
df_male_local = df_male

# %%
df_male_local.update(df_female)

# %%
df_male_local
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# ..           ...       ...     ...                             ...   ...
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 889          890         1       1           Behr, Mr. Karl Howell  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0    22.0      1      0         A/5 21171   7.2500   NaN        S
# 4    35.0      0      0            373450   8.0500   NaN        S
# 5     NaN      0      0            330877   8.4583   NaN        Q
# 6    54.0      0      0             17463  51.8625   E46        S
# 7     2.0      3      1            349909  21.0750   NaN        S
# ..    ...    ...    ...               ...      ...   ...      ...
# 883  28.0      0      0  C.A./SOTON 34068  10.5000   NaN        S
# 884  25.0      0      0   SOTON/OQ 392076   7.0500   NaN        S
# 886  27.0      0      0            211536  13.0000   NaN        S
# 889  26.0      0      0            111369  30.0000  C148        C
# 890  32.0      0      0            370376   7.7500   NaN        Q
#
# [577 rows x 12 columns]

# %%
df_male_local.iloc[101,0:]
# Out:
# PassengerId                    159
# Survived                         0
# Pclass                           3
# Name           Smiljanic, Mr. Mile
# Sex                           male
# Age                            NaN
# SibSp                            0
# Parch                            0
# Ticket                      315037
# Fare                        8.6625
# Cabin                          NaN
# Embarked                         S
# Name: 158, dtype: object

# %%
df_male_local.iloc[10]
# Out:
# PassengerId                       22
# Survived                           1
# Pclass                             2
# Name           Beesley, Mr. Lawrence
# Sex                             male
# Age                               34
# SibSp                              0
# Parch                              0
# Ticket                        248698
# Fare                              13
# Cabin                            D56
# Embarked                           S
# Name: 21, dtype: object

# %%
df_male_local.iloc[[10]]
# Out:
#     PassengerId  Survived  Pclass                   Name   Sex   Age  SibSp  \
# 21           22         1       2  Beesley, Mr. Lawrence  male  34.0      0
#
#     Parch  Ticket  Fare Cabin Embarked
# 21      0  248698  13.0   D56        S

# %%
df_row_selected = df_male_local.iloc[[10]]

# %%
df_row_selected
# Out:
#     PassengerId  Survived  Pclass                   Name   Sex   Age  SibSp  \
# 21           22         1       2  Beesley, Mr. Lawrence  male  34.0      0
#
#     Parch  Ticket  Fare Cabin Embarked
# 21      0  248698  13.0   D56        S

# %%
df_row_selected.loc[df_row_selected['PassengerId'] == 22,'Survived']
# Out:
# 21    1
# Name: Survived, dtype: int64

# %%
df_row_selected.loc[df_row_selected['PassengerId'] == 22,'Survived'] = 5
# Out:
# /Users/avkash/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:965: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
df_row_selected
# Out:
#     PassengerId  Survived  Pclass                   Name   Sex   Age  SibSp  \
# 21           22         5       2  Beesley, Mr. Lawrence  male  34.0      0
#
#     Parch  Ticket  Fare Cabin Embarked
# 21      0  248698  13.0   D56        S

# %%
df_male_local.update(df_row_selected)
# Out:
# /Users/avkash/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:5732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[col] = expressions.where(mask, this, that)

# %%
df_male_local.iloc[10]
# Out:
# PassengerId                       22
# Survived                           5
# Pclass                             2
# Name           Beesley, Mr. Lawrence
# Sex                             male
# Age                               34
# SibSp                              0
# Parch                              0
# Ticket                        248698
# Fare                              13
# Cabin                            D56
# Embarked                           S
# Name: 21, dtype: object

# %% [markdown]
# # Bonus Tip: Reading Clipboard

# %%
dfc = pd.read_clipboard()

# %%
dfc
# Out:
#                           PassengerId   Survived   Pclass  Name   Sex  Age  \
# 0   1   0   3   Braund,           Mr.       Owen   Harris  male  22.0    1
# 4   5   0   3   Allen,            Mr.    William    Henry  male  35.0    0
# 5   6   0   3   Moran,            Mr.      James     male   NaN     0    0
# 6   7   0   1   McCarthy,         Mr.    Timothy        J  male  54.0    0
# 7   8   0   3   Palsson,      Master.      Gosta  Leonard  male   2.0    3
# ... ... ... ... ...               ...        ...      ...   ...   ...  ...
# 883 884 0   2   Banfield,         Mr.  Frederick    James  male  28.0    0
# 884 885 0   3   Sutehall,         Mr.      Henry       Jr  male  25.0    0
# 886 887 0   2   Montvila,        Rev.     Juozas     male  27.0     0    0
# 889 890 1   1   Behr,             Mr.       Karl   Howell  male  26.0    0
# 890 891 0   3   Dooley,           Mr.    Patrick     male  32.0     0    0
#
#                             SibSp       Parch       Ticket     Fare Cabin  \
# 0   1   0   3   Braund,         0         A/5   21171.0000   7.2500   NaN
# 4   5   0   3   Allen,          0      373450       8.0500      NaN     S
# 5   6   0   3   Moran,     330877      8.4583          NaN        Q  None
# 6   7   0   1   McCarthy,       0       17463      51.8625      E46     S
# 7   8   0   3   Palsson,        1      349909      21.0750      NaN     S
# ... ... ... ... ...           ...         ...          NaN     None  None
# 883 884 0   2   Banfield,       0  C.A./SOTON   34068.0000  10.5000   NaN
# 884 885 0   3   Sutehall,       0    SOTON/OQ  392076.0000   7.0500   NaN
# 886 887 0   2   Montvila,  211536     13.0000          NaN        S  None
# 889 890 1   1   Behr,           0      111369      30.0000     C148     C
# 890 891 0   3   Dooley,    370376      7.7500          NaN        Q  None
#
#                           Embarked
# 0   1   0   3   Braund,          S
# 4   5   0   3   Allen,        None
# 5   6   0   3   Moran,        None
# 6   7   0   1   McCarthy,     None
# 7   8   0   3   Palsson,      None
# ... ... ... ... ...           None
# 883 884 0   2   Banfield,        S
# 884 885 0   3   Sutehall,        S
# 886 887 0   2   Montvila,     None
# 889 890 1   1   Behr,         None
# 890 891 0   3   Dooley,       None

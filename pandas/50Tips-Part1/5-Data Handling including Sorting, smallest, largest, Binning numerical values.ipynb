# %%
import pandas as pd

# %%
local_source = '../../datasets/titanic.csv'
df = pd.read_csv(local_source)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # 5.1 Sorting DataFrame based on column values

# %%
df_with_index = pd.read_csv(local_source, index_col='Name')

# %%
df_with_index
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
# ...                                                         ...       ...
# Montvila, Rev. Juozas                                       887         0
# Graham, Miss. Margaret Edith                                888         1
# Johnston, Miss. Catherine Helen "Carrie"                    889         0
# Behr, Mr. Karl Howell                                       890         1
# Dooley, Mr. Patrick                                         891         0
#
# ...

# %%
df_with_index.sort_index(axis = 0)
# Out:
#                                        PassengerId  Survived  Pclass     Sex  \
# Name
# Abbing, Mr. Anthony                            846         0       3    male
# Abbott, Mr. Rossmore Edward                    747         0       3    male
# Abbott, Mrs. Stanton (Rosa Hunt)               280         1       3  female
# Abelson, Mr. Samuel                            309         0       2    male
# Abelson, Mrs. Samuel (Hannah Wizosky)          875         1       2  female
# ...                                            ...       ...     ...     ...
# de Mulder, Mr. Theodore                        287         1       3    male
# de Pelsmaeker, Mr. Alfons                      283         0       3    male
# del Carlo, Mr. Sebastiano                      362         0       2    male
# van Billiard, Mr. Austin Blyler                154         0       3    male
# van Melkebeke, Mr. Philemon                    869         0       3    male
#
# ...

# %%
df_with_index.sort_index(axis = 0, ascending=False)
# Out:
#                                        PassengerId  Survived  Pclass     Sex  \
# Name
# van Melkebeke, Mr. Philemon                    869         0       3    male
# van Billiard, Mr. Austin Blyler                154         0       3    male
# del Carlo, Mr. Sebastiano                      362         0       2    male
# de Pelsmaeker, Mr. Alfons                      283         0       3    male
# de Mulder, Mr. Theodore                        287         1       3    male
# ...                                            ...       ...     ...     ...
# Abelson, Mrs. Samuel (Hannah Wizosky)          875         1       2  female
# Abelson, Mr. Samuel                            309         0       2    male
# Abbott, Mrs. Stanton (Rosa Hunt)               280         1       3  female
# Abbott, Mr. Rossmore Edward                    747         0       3    male
# Abbing, Mr. Anthony                            846         0       3    male
#
# ...

# %%
df_with_index.sort_values('PassengerId')
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
# ...                                                         ...       ...
# Montvila, Rev. Juozas                                       887         0
# Graham, Miss. Margaret Edith                                888         1
# Johnston, Miss. Catherine Helen "Carrie"                    889         0
# Behr, Mr. Karl Howell                                       890         1
# Dooley, Mr. Patrick                                         891         0
#
# ...

# %%
df_with_index.sort_values('Ticket')
# Out:
#                                                     PassengerId  Survived  \
# Name
# Maioni, Miss. Roberta                                       505         1
# Cherry, Miss. Gladys                                        258         1
# Rothes, the Countess. of (Lucy Noel Martha Dyer...          760         1
# Taussig, Mr. Emil                                           263         0
# Taussig, Mrs. Emil (Tillie Mandelbaum)                      559         1
# ...                                                         ...       ...
# Harknett, Miss. Alice Phoebe                                236         0
# Chaffee, Mr. Herbert Fuller                                  93         0
# Harris, Mr. Walter                                          220         0
# Crosby, Miss. Harriet R                                     541         1
# Crosby, Capt. Edward Gifford                                746         0
#
# ...

# %%
df_with_index.sort_values('Pclass')
# Out:
#                                                     PassengerId  Survived  \
# Name
# Dodge, Master. Washington                                   446         1
# Hays, Miss. Margaret Bechstein                              311         1
# Francatelli, Miss. Laura Mabel                              310         1
# Penasco y Castellana, Mrs. Victor de Satode (Ma...          308         1
# Fleming, Miss. Margaret                                     307         1
# ...                                                         ...       ...
# Gustafsson, Mr. Karl Gideon                                 380         0
# Nakid, Miss. Maria ("Mary")                                 382         1
# Tikkanen, Mr. Juho                                          383         0
# Wiklund, Mr. Jakob Alfred                                   372         0
# Dooley, Mr. Patrick                                         891         0
#
# ...

# %%
df_with_index.sort_values('Pclass', ascending= False)
# Out:
#                                                   PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                     1         0
# Webber, Mr. James                                         512         0
# Calic, Mr. Petar                                          501         0
# Canavan, Miss. Mary                                       502         0
# O'Sullivan, Miss. Bridget Mary                            503         0
# ...                                                       ...       ...
# White, Mr. Richard Frasar                                 103         0
# Mayne, Mlle. Berthe Antonine ("Mrs de Villiers")          711         1
# Klaber, Mr. Herman                                        712         0
# Taylor, Mr. Elmer Zebley                                  713         1
# Dodge, Master. Washington                                 446         1
#
#                                                   Pclass     Sex   Age  SibSp  \
# Name
# ...

# %% [markdown]
# # 5.2 Sorting based on 2 columns and their desired order

# %%
df_with_index.sort_values(['Name','Pclass'], ascending= [True, True])
# Out:
#                                        PassengerId  Survived  Pclass     Sex  \
# Name
# Abbing, Mr. Anthony                            846         0       3    male
# Abbott, Mr. Rossmore Edward                    747         0       3    male
# Abbott, Mrs. Stanton (Rosa Hunt)               280         1       3  female
# Abelson, Mr. Samuel                            309         0       2    male
# Abelson, Mrs. Samuel (Hannah Wizosky)          875         1       2  female
# ...                                            ...       ...     ...     ...
# de Mulder, Mr. Theodore                        287         1       3    male
# de Pelsmaeker, Mr. Alfons                      283         0       3    male
# del Carlo, Mr. Sebastiano                      362         0       2    male
# van Billiard, Mr. Austin Blyler                154         0       3    male
# van Melkebeke, Mr. Philemon                    869         0       3    male
#
# ...

# %%
df_with_index.sort_values(['Ticket','Sex', 'Pclass'], ascending= (False, True, False))
# Out:
#                                                     PassengerId  Survived  \
# Name
# Crosby, Miss. Harriet R                                     541         1
# Crosby, Capt. Edward Gifford                                746         0
# Harris, Mr. Walter                                          220         0
# Chaffee, Mr. Herbert Fuller                                  93         0
# Harknett, Miss. Alice Phoebe                                236         0
# ...                                                         ...       ...
# Taussig, Miss. Ruth                                         586         1
# Taussig, Mr. Emil                                           263         0
# Cherry, Miss. Gladys                                        258         1
# Maioni, Miss. Roberta                                       505         1
# Rothes, the Countess. of (Lucy Noel Martha Dyer...          760         1
#
# ...

# %%
df_with_index
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
# ...                                                         ...       ...
# Montvila, Rev. Juozas                                       887         0
# Graham, Miss. Margaret Edith                                888         1
# Johnston, Miss. Catherine Helen "Carrie"                    889         0
# Behr, Mr. Karl Howell                                       890         1
# Dooley, Mr. Patrick                                         891         0
#
# ...

# %% [markdown]
# # 5.3 Getting Largers values in DataFrame based on column

# %%
df.nlargest(5, ['Age'])
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                   Svensson, Mr. Johan
# 96            97         0       1             Goldschmidt, Mr. George B
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 116          117         0       3                  Connors, Mr. Patrick
#
#       Sex   Age  SibSp  Parch    Ticket     Fare Cabin Embarked
# 630  male  80.0      0      0     27042  30.0000   A23        S
# 851  male  74.0      0      0    347060   7.7750   NaN        S
# 96   male  71.0      0      0  PC 17754  34.6542    A5        C
# 493  male  71.0      0      0  PC 17609  49.5042   NaN        C
# 116  male  70.5      0      0    370369   7.7500   NaN        Q

# %%
df.nlargest(1000,['Age'])
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                   Svensson, Mr. Johan
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 96            97         0       1             Goldschmidt, Mr. George B
# 116          117         0       3                  Connors, Mr. Patrick
# ..           ...       ...     ...                                   ...
# 78            79         1       2         Caldwell, Master. Alden Gates
# 644          645         1       3                Baclini, Miss. Eugenie
# 469          470         1       3         Baclini, Miss. Helene Barbara
# 755          756         1       2             Hamalainen, Master. Viljo
# 803          804         1       3       Thomas, Master. Assad Alexander
#
#         Sex    Age  SibSp  Parch    Ticket     Fare Cabin Embarked
# ...

# %% [markdown]
# # 5.4 Getting Smallers values in DataFrame based on column

# %%
df.nsmallest(5, ['Age'])
# Out:
#      PassengerId  Survived  Pclass                             Name     Sex  \
# 803          804         1       3  Thomas, Master. Assad Alexander    male
# 755          756         1       2        Hamalainen, Master. Viljo    male
# 469          470         1       3    Baclini, Miss. Helene Barbara  female
# 644          645         1       3           Baclini, Miss. Eugenie  female
# 78            79         1       2    Caldwell, Master. Alden Gates    male
#
#       Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# 803  0.42      0      1    2625   8.5167   NaN        C
# 755  0.67      1      1  250649  14.5000   NaN        S
# 469  0.75      2      1    2666  19.2583   NaN        C
# 644  0.75      2      1    2666  19.2583   NaN        C
# 78   0.83      0      2  248738  29.0000   NaN        S

# %%
df.nsmallest(500, ['Age'])
# Out:
#      PassengerId  Survived  Pclass                             Name     Sex  \
# 803          804         1       3  Thomas, Master. Assad Alexander    male
# 755          756         1       2        Hamalainen, Master. Viljo    male
# 469          470         1       3    Baclini, Miss. Helene Barbara  female
# 644          645         1       3           Baclini, Miss. Eugenie  female
# 78            79         1       2    Caldwell, Master. Alden Gates    male
# ..           ...       ...     ...                              ...     ...
# 812          813         0       2        Slemen, Mr. Richard James    male
# 847          848         0       3               Markoff, Mr. Marin    male
# 179          180         0       3              Leonard, Mr. Lionel    male
# 189          190         0       3              Turcin, Mr. Stjepan    male
# 265          266         0       2                Reeves, Mr. David    male
#
# ...

# %% [markdown]
# # 5.5 Pivoting DataFrame - Converting a column to row name/index

# %%
df_for_pivot = pd.read_csv(local_source)

# %%
df_for_pivot
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df_pivot = df_for_pivot.pivot(index ='Sex', columns ='Name')

# %%
df_pivot
# Out:
#                PassengerId                              \
# Name   Abbing, Mr. Anthony Abbott, Mr. Rossmore Edward
# Sex
# female                 NaN                         NaN
# male                 846.0                       747.0
#
#                                                              \
# Name   Abbott, Mrs. Stanton (Rosa Hunt) Abelson, Mr. Samuel
# Sex
# female                            280.0                 NaN
# male                                NaN               309.0
#
#                                                                              \
# Name   Abelson, Mrs. Samuel (Hannah Wizosky) Adahl, Mr. Mauritz Nils Martin
# Sex
# female                                 875.0                            NaN
# male                                     NaN                          366.0
#
#                                                                        \
# Name   Adams, Mr. John Ahlin, Mrs. Johan (Johanna Persdotter Larsson)
# Sex
# ...

# %%
df_pivot.shape
# Out:
# (2, 8910)

# %%
df_pivot_change = df_for_pivot.pivot(index ='Name', columns ='Sex')

# %%
df_pivot_change
# Out:
#                                       PassengerId        Survived      Pclass  \
# Sex                                        female   male   female male female
# Name
# Abbing, Mr. Anthony                           NaN  846.0      NaN  0.0    NaN
# Abbott, Mr. Rossmore Edward                   NaN  747.0      NaN  0.0    NaN
# Abbott, Mrs. Stanton (Rosa Hunt)            280.0    NaN      1.0  NaN    3.0
# Abelson, Mr. Samuel                           NaN  309.0      NaN  0.0    NaN
# Abelson, Mrs. Samuel (Hannah Wizosky)       875.0    NaN      1.0  NaN    2.0
# ...                                           ...    ...      ...  ...    ...
# de Mulder, Mr. Theodore                       NaN  287.0      NaN  1.0    NaN
# de Pelsmaeker, Mr. Alfons                     NaN  283.0      NaN  0.0    NaN
# del Carlo, Mr. Sebastiano                     NaN  362.0      NaN  0.0    NaN
# van Billiard, Mr. Austin Blyler               NaN  154.0      NaN  0.0    NaN
# ...

# %%
df_3_columns = df_for_pivot[['Pclass', 'Sex', 'Name']]

# %%
df_3_columns
# Out:
#      Pclass     Sex                                               Name
# 0         3    male                            Braund, Mr. Owen Harris
# 1         1  female  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         3  female                             Heikkinen, Miss. Laina
# 3         1  female       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         3    male                           Allen, Mr. William Henry
# ..      ...     ...                                                ...
# 886       2    male                              Montvila, Rev. Juozas
# 887       1  female                       Graham, Miss. Margaret Edith
# 888       3  female           Johnston, Miss. Catherine Helen "Carrie"
# 889       1    male                              Behr, Mr. Karl Howell
# 890       3    male                                Dooley, Mr. Patrick
#
# [891 rows x 3 columns]

# %%
df_pivot = df_3_columns.pivot(index ='Pclass', columns ='Name')

# %%
df_pivot
# Out:
#                        Sex                              \
# Name   Abbing, Mr. Anthony Abbott, Mr. Rossmore Edward
# Pclass
# 1                      NaN                         NaN
# 2                      NaN                         NaN
# 3                     male                        male
#
#                                                              \
# Name   Abbott, Mrs. Stanton (Rosa Hunt) Abelson, Mr. Samuel
# Pclass
# 1                                   NaN                 NaN
# 2                                   NaN                male
# 3                                female                 NaN
#
#                                                                              \
# Name   Abelson, Mrs. Samuel (Hannah Wizosky) Adahl, Mr. Mauritz Nils Martin
# Pclass
# 1                                        NaN                            NaN
# 2                                     female                            NaN
# ...

# %% [markdown]
# # 5.6 Capitalizing all values in the specific Column

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Sex'] = df['Sex'].str.capitalize()

# %%
df['Ticket'] = df['Ticket'].str.capitalize()

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    Male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  Female  38.0      1
# 2                               Heikkinen, Miss. Laina  Female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  Female  35.0      1
# 4                             Allen, Mr. William Henry    Male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # 5.7 Creating Bins from numeric values

# %%
df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    Male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  Female  38.0      1
# 2                             Heikkinen, Miss. Laina  Female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  Female  35.0      1
# 4                           Allen, Mr. William Henry    Male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          Pc 17599  71.2833   C85        C
# 2      0  Ston/o2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df['Age'].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
df['bins'] = pd.cut(df['Age'], bins=20, include_lowest=True)

# %%
df.sort_values('bins')
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 164          165         0       3              Panula, Master. Eino Viljami
# 824          825         0       3              Panula, Master. Urho Abraham
# 827          828         1       2                     Mallet, Master. Andre
# 691          692         1       3                        Karun, Miss. Manca
# 479          480         1       3                  Hirvonen, Miss. Hildur E
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
df.sort_values('bins', ascending=False)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 630          631         1       1      Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                       Svensson, Mr. Johan
# 672          673         0       2               Mitchell, Mr. Henry Michael
# 745          746         0       1              Crosby, Capt. Edward Gifford
# 493          494         0       1                   Artagaveytia, Mr. Ramon
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
import pandas as pd

# %%
loan_data = pd.read_csv("loan-train.csv")

# %%
loan_data
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
loan_data['Loan_ID'].unique()
# Out:
# array(['LP001002', 'LP001003', 'LP001005', 'LP001006', 'LP001008',
#        'LP001011', 'LP001013', 'LP001014', 'LP001018', 'LP001020',
#        'LP001024', 'LP001027', 'LP001028', 'LP001029', 'LP001030',
#        'LP001032', 'LP001034', 'LP001036', 'LP001038', 'LP001041',
#        'LP001043', 'LP001046', 'LP001047', 'LP001050', 'LP001052',
#        'LP001066', 'LP001068', 'LP001073', 'LP001086', 'LP001087',
#        'LP001091', 'LP001095', 'LP001097', 'LP001098', 'LP001100',
#        'LP001106', 'LP001109', 'LP001112', 'LP001114', 'LP001116',
#        'LP001119', 'LP001120', 'LP001123', 'LP001131', 'LP001136',
#        'LP001137', 'LP001138', 'LP001144', 'LP001146', 'LP001151',
#        'LP001155', 'LP001157', 'LP001164', 'LP001179', 'LP001186',
#        'LP001194', 'LP001195', 'LP001197', 'LP001198', 'LP001199',
#        'LP001205', 'LP001206', 'LP001207', 'LP001213', 'LP001222',
#        'LP001225', 'LP001228', 'LP001233', 'LP001238', 'LP001241',
# ...

# %%
len(loan_data['Loan_ID'].unique())
# Out:
# 614

# %%
loan_data[['Loan_ID']]
# Out:
#       Loan_ID
# 0    LP001002
# 1    LP001003
# 2    LP001005
# 3    LP001006
# 4    LP001008
# ..        ...
# 609  LP002978
# 610  LP002979
# 611  LP002983
# 612  LP002984
# 613  LP002990
#
# [614 rows x 1 columns]

# %%
local_id_data = loan_data[['Loan_ID']]

# %%
local_id_data['Loan_ID']
# Out:
# 0      LP001002
# 1      LP001003
# 2      LP001005
# 3      LP001006
# 4      LP001008
#          ...
# 609    LP002978
# 610    LP002979
# 611    LP002983
# 612    LP002984
# 613    LP002990
# Name: Loan_ID, Length: 614, dtype: object

# %%
# !ls
# Out:
# Loan_Prediction-with-FE-and-data-augmentation.ipynb
# Loan_Prediction-with-feature-engineering.ipynb
# Loan_Prediction.ipynb
# Untitled.ipynb
# ZipCodeLivingRank.csv
# loan-test.csv
# loan-train.csv
# sf_zipcodes.csv

# %%
sf = pd.read_csv("sf_zipcodes.csv", delimiter="\t")

# %%
sf.sample()
# Out:
#     ZipCode           City                County
# 14    94117  San Francisco  San Francisco County

# %%
list(sf['ZipCode'])
# Out:
# [94101,
#  94102,
#  94103,
#  94104,
#  94105,
#  94107,
#  94108,
#  94109,
#  94110,
#  94111,
#  94112,
#  94114,
#  94115,
#  94116,
#  94117,
#  94118,
#  94119,
#  94120,
#  94121,
#  94122,
#  94123,
#  94124,
#  94125,
#  94126,
#  94127,
#  94129,
#  94130,
#  94131,
#  94132,
#  94133,
#  94134,
#  94140,
#  94141,
#  94142,
#  94146,
#  94147,
#  94157,
#  94159,
#  94164,
#  94165,
#  94166,
#  94167,
#  94168,
#  94169,
#  94170,
#  94172,
#  94188]

# %%
sf[['ZipCode']]
# Out:
#     ZipCode
# 0     94101
# 1     94102
# 2     94103
# 3     94104
# 4     94105
# 5     94107
# 6     94108
# 7     94109
# 8     94110
# 9     94111
# 10    94112
# 11    94114
# 12    94115
# 13    94116
# 14    94117
# 15    94118
# 16    94119
# 17    94120
# 18    94121
# 19    94122
# 20    94123
# 21    94124
# 22    94125
# 23    94126
# 24    94127
# 25    94129
# 26    94130
# 27    94131
# 28    94132
# 29    94133
# 30    94134
# 31    94140
# 32    94141
# 33    94142
# 34    94146
# 35    94147
# 36    94157
# 37    94159
# 38    94164
# 39    94165
# 40    94166
# 41    94167
# 42    94168
# 43    94169
# 44    94170
# 45    94172
# 46    94188

# %%
import random
unique_zips = set(sf.ZipCode.unique())
assign = lambda x: random.choice(list(unique_zips - {x}))

# %%
local_id_data['ZipCode'] = local_id_data.Loan_ID.apply(assign)
# Out:
# /Users/avkash/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
local_id_data
# Out:
#       Loan_ID  ZipCode
# 0    LP001002    94188
# 1    LP001003    94164
# 2    LP001005    94120
# 3    LP001006    94104
# 4    LP001008    94169
# ..        ...      ...
# 609  LP002978    94118
# 610  LP002979    94170
# 611  LP002983    94167
# 612  LP002984    94121
# 613  LP002990    94114
#
# [614 rows x 2 columns]

# %%
# !ls
# Out:
# Loan_Prediction-with-FE-and-data-augmentation.ipynb
# Loan_Prediction-with-feature-engineering.ipynb
# Loan_Prediction.ipynb
# Untitled.ipynb
# ZipCodeLivingRank.csv
# loan-test.csv
# loan-train.csv
# sf_zipcodes.csv

# %%
living = pd.read_csv("ZipCodeLivingRank.csv")

# %%
living
# Out:
#     ZipCode  LivingRank
# 0     94101           1
# 1     94102           2
# 2     94103           3
# 3     94104           4
# 4     94105           5
# 5     94107           1
# 6     94108           2
# 7     94109           3
# 8     94110           4
# 9     94111           5
# 10    94112           1
# 11    94114           2
# 12    94115           3
# 13    94116           4
# 14    94117           5
# 15    94118           1
# 16    94119           2
# 17    94120           3
# 18    94121           4
# 19    94122           5
# 20    94123           2
# 21    94124           3
# 22    94125           4
# 23    94126           3
# 24    94127           2
# 25    94129           1
# 26    94130           2
# 27    94131           3
# 28    94132           4
# 29    94133           5
# 30    94134           5
# 31    94140           3
# 32    94141           3
# 33    94142           3
# 34    94146           2
# 35    94147           3
# 36    94157           2
# ...

# %%
final_df = pd.merge(local_id_data, living)

# %%
final_df
# Out:
#       Loan_ID  ZipCode  LivingRank
# 0    LP001002    94188           1
# 1    LP001106    94188           1
# 2    LP001137    94188           1
# 3    LP001245    94188           1
# 4    LP001253    94188           1
# ..        ...      ...         ...
# 609  LP002201    94121           4
# 610  LP002231    94121           4
# 611  LP002364    94121           4
# 612  LP002813    94121           4
# 613  LP002984    94121           4
#
# [614 rows x 3 columns]

# %%
final_df
# Out:
#       Loan_ID  ZipCode  LivingRank
# 0    LP001002    94188           1
# 1    LP001106    94188           1
# 2    LP001137    94188           1
# 3    LP001245    94188           1
# 4    LP001253    94188           1
# ..        ...      ...         ...
# 609  LP002201    94121           4
# 610  LP002231    94121           4
# 611  LP002364    94121           4
# 612  LP002813    94121           4
# 613  LP002984    94121           4
#
# [614 rows x 3 columns]

# %%
final_df.to_csv('zipwithliving_index.csv', index=False)

# %%
# !ls
# Out:
# Loan_Prediction-with-FE-and-data-augmentation.ipynb
# Loan_Prediction-with-feature-engineering.ipynb
# Loan_Prediction.ipynb
# Untitled.ipynb
# ZipCodeLivingRank.csv
# loan-test.csv
# loan-train.csv
# sf_zipcodes.csv
# zipwithliving_index.csv

# %%
import pandas
import h2o

# %%
h2o.connect()
# Out:
# Connecting to H2O server at http://localhost:54321 ... successful.
# --------------------------  ----------------------------------------------------------------------------
# H2O_cluster_uptime:         1 hour 41 mins
# H2O_cluster_timezone:       America/Los_Angeles
# H2O_data_parsing_timezone:  UTC
# H2O_cluster_version:        3.36.0.2
# H2O_cluster_version_age:    16 days
# H2O_cluster_name:           H2O_from_python_avkash_8eyink
# H2O_cluster_total_nodes:    1
# H2O_cluster_free_memory:    7.999 Gb
# H2O_cluster_total_cores:    16
# H2O_cluster_allowed_cores:  16
# H2O_cluster_status:         locked, healthy
# H2O_connection_url:         http://localhost:54321
# H2O_connection_proxy:       {"http": null, "https": null}
# H2O_internal_security:      False
# H2O_API_Extensions:         Amazon S3, XGBoost, Algos, Infogram, AutoML, Core V3, TargetEncoder, Core V4
# Python_version:             3.7.6 final
# ...

# %%
h2o.ls()
# Out:
#                                                   key
# 0                 GBM_model_python_1644623179919_1140
# 1                 GLM_model_python_1644623179919_1137
# 2            gbm-c732219d-39da-4a45-bc6d-ee1e8293ab46
# 3                                       loan_test.hex
# 4                                      loan_train.hex
# 5                                     loan_train1.hex
# 6   modelmetrics_GBM_model_python_1644623179919_11...
# 7   modelmetrics_GBM_model_python_1644623179919_11...
# 8   modelmetrics_GLM_model_python_1644623179919_11...
# 9   modelmetrics_GLM_model_python_1644623179919_11...
# 10  modelmetrics_gbm-c732219d-39da-4a45-bc6d-ee1e8...
# 11           pdp-1750626f-e852-4ae0-9c57-cfb1404bc245
# 12           pdp-b761dd6b-7e38-4cfe-a6e0-289a5da14588
# 13    prediction-427224b8-ca68-4ca3-a799-fdcd62aa62f3
# 14                                      py_1_sid_bc1a
# 15                                      py_3_sid_bc1a
# ...

# %%
loan_frame_h2o = h2o.get_frame('loan_train.hex')

# %%
loan_frame_h2o
# Out:
# <table>
# <thead>
# <tr><th>Loan_ID  </th><th>Gender  </th><th>Married  </th><th>Dependents  </th><th>Education   </th><th>Self_Employed  </th><th style="text-align: right;">  ApplicantIncome</th><th style="text-align: right;">  CoapplicantIncome</th><th style="text-align: right;">  LoanAmount</th><th style="text-align: right;">  Loan_Amount_Term</th><th style="text-align: right;">  Credit_History</th><th>Property_Area  </th><th>Loan_Status  </th></tr>
# </thead>
# <tbody>
# <tr><td>LP001002 </td><td>Male    </td><td>No       </td><td>0           </td><td>Graduate    </td><td>No             </td><td style="text-align: right;">             5849</td><td style="text-align: right;">                  0</td><td style="text-align: right;">         nan</td><td style="text-align: right;">               360</td><td style="text-align: right;">               1</td><td>Urban          </td><td>Y            </td></tr>
# ...

# %%
type(loan_frame_h2o)
# Out:
# h2o.frame.H2OFrame

# %%
df = loan_frame_h2o.as_data_frame()

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
h2o_frame_from_pandas = h2o.H2OFrame(df)
# Out:
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%

# %%
h2o_frame_from_pandas
# Out:
# <table>
# <thead>
# <tr><th>Loan_ID  </th><th>Gender  </th><th>Married  </th><th style="text-align: right;">  Dependents</th><th>Education   </th><th>Self_Employed  </th><th style="text-align: right;">  ApplicantIncome</th><th style="text-align: right;">  CoapplicantIncome</th><th style="text-align: right;">  LoanAmount</th><th style="text-align: right;">  Loan_Amount_Term</th><th style="text-align: right;">  Credit_History</th><th>Property_Area  </th><th>Loan_Status  </th></tr>
# </thead>
# <tbody>
# <tr><td>LP001002 </td><td>Male    </td><td>No       </td><td style="text-align: right;">           0</td><td>Graduate    </td><td>No             </td><td style="text-align: right;">             5849</td><td style="text-align: right;">                  0</td><td style="text-align: right;">         nan</td><td style="text-align: right;">               360</td><td style="text-align: right;">               1</td><td>Urban          </td><td>Y            </td></tr>
# ...

# %%
h2o.ls()
# Out:
#                                                   key
# 0                 GBM_model_python_1644623179919_1140
# 1                 GLM_model_python_1644623179919_1137
# 2   Key_Frame__upload_aa5fc0b6be9a488eea6d530935c1...
# 3            gbm-c732219d-39da-4a45-bc6d-ee1e8293ab46
# 4                                       loan_test.hex
# 5                                      loan_train.hex
# 6                                     loan_train1.hex
# 7   modelmetrics_GBM_model_python_1644623179919_11...
# 8   modelmetrics_GBM_model_python_1644623179919_11...
# 9   modelmetrics_GLM_model_python_1644623179919_11...
# 10  modelmetrics_GLM_model_python_1644623179919_11...
# 11  modelmetrics_gbm-c732219d-39da-4a45-bc6d-ee1e8...
# 12           pdp-1750626f-e852-4ae0-9c57-cfb1404bc245
# 13           pdp-b761dd6b-7e38-4cfe-a6e0-289a5da14588
# 14    prediction-427224b8-ca68-4ca3-a799-fdcd62aa62f3
# 15                                      py_1_sid_bc1a
# ...

# %%
h2o_frame_from_pandas_x = h2o.H2OFrame(df)
# Out:
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%

# %%
h2o.ls()
# Out:
#                                                   key
# 0                 GBM_model_python_1644623179919_1140
# 1                 GLM_model_python_1644623179919_1137
# 2   Key_Frame__upload_93767230c8074858fd29abea9a00...
# 3   Key_Frame__upload_aa5fc0b6be9a488eea6d530935c1...
# 4            gbm-c732219d-39da-4a45-bc6d-ee1e8293ab46
# 5                                       loan_test.hex
# 6                                      loan_train.hex
# 7                                     loan_train1.hex
# 8   modelmetrics_GBM_model_python_1644623179919_11...
# 9   modelmetrics_GBM_model_python_1644623179919_11...
# 10  modelmetrics_GLM_model_python_1644623179919_11...
# 11  modelmetrics_GLM_model_python_1644623179919_11...
# 12  modelmetrics_gbm-c732219d-39da-4a45-bc6d-ee1e8...
# 13           pdp-1750626f-e852-4ae0-9c57-cfb1404bc245
# 14           pdp-b761dd6b-7e38-4cfe-a6e0-289a5da14588
# 15    prediction-427224b8-ca68-4ca3-a799-fdcd62aa62f3
# ...

# %%
type(h2o_frame_from_pandas_x)
# Out:
# h2o.frame.H2OFrame

# %%
h2o_frame_from_pandas_x.tail()
# Out:
# <table>
# <thead>
# <tr><th>Loan_ID  </th><th>Gender  </th><th>Married  </th><th style="text-align: right;">  Dependents</th><th>Education   </th><th>Self_Employed  </th><th style="text-align: right;">  ApplicantIncome</th><th style="text-align: right;">  CoapplicantIncome</th><th style="text-align: right;">  LoanAmount</th><th style="text-align: right;">  Loan_Amount_Term</th><th style="text-align: right;">  Credit_History</th><th>Property_Area  </th><th>Loan_Status  </th></tr>
# </thead>
# <tbody>
# <tr><td>LP002959 </td><td>Female  </td><td>Yes      </td><td style="text-align: right;">           1</td><td>Graduate    </td><td>No             </td><td style="text-align: right;">            12000</td><td style="text-align: right;">                  0</td><td style="text-align: right;">         496</td><td style="text-align: right;">               360</td><td style="text-align: right;">               1</td><td>Semiurban      </td><td>Y            </td></tr>
# ...

# %%
df.hist
# Out:
# <bound method hist_frame of       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...
